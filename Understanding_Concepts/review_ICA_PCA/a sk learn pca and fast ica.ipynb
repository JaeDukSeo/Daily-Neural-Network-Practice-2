# %%
# import library
# ========= choice of library ====
import tensorflow as tf
import numpy as np
import sys, os,cv2
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from skimage.transform import resize
from scipy.misc import imread
from imgaug import augmenters as iaa
import nibabel as nib
import imgaug as ia
from scipy.ndimage import zoom
from sklearn.utils import shuffle
import matplotlib.animation as animation

plt.style.use('seaborn-white')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
np.random.seed(6278)
tf.set_random_seed(6728)
ia.seed(6278)

# Generate training data
import tensorflow as tf
old_v = tf.logging.get_verbosity()
tf.logging.set_verbosity(tf.logging.ERROR)
from tensorflow.examples.tutorials.mnist import input_data
# ========= choice of library ====

# %%
# Get the certain STL 10 Data
from skimage import util 
data_location = "../../Dataset/STL10/img/2/"
train_data = []  # create an empty list
for dirName, subdirList, fileList in sorted(os.walk(data_location)):
    for filename in fileList:
        if ".png" in filename.lower() :
            train_data.append(os.path.join(dirName,filename))

image_resize_px = 64
train_batch = np.zeros(shape=(len(train_data),image_resize_px,image_resize_px))
for file_index in range(len(train_data)):
    train_batch[file_index] = resize(imread(train_data[file_index],mode='L'),(image_resize_px,image_resize_px))
            
# print out the data shape and the max and min value
train_batch = np.expand_dims(train_batch,3)
print('Train batch, min, max : ',train_batch.shape,train_batch.min(),train_batch.max())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   del sys.path[0]
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\transform\_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# Train batch, min, max :  (500, 64, 64, 1) 0.0 1.0

# %%
# view random 100 images
idx = np.random.permutation(len(train_batch))
train_batch = train_batch[idx]
fig=plt.figure(figsize=(30, 30))
columns = 10;rows = 10
for i in range(1, columns*rows +1):
    fig.add_subplot(rows, columns, i)
    plt.imshow(np.squeeze(train_batch[i-1]),cmap='gray')
    plt.axis('off')
plt.show()

# %%
# perform pca from the sklearn library
sk_test_data = train_batch.reshape(500,-1)
print(sk_test_data.shape)
from sklearn.decomposition import PCA
sk_pca = PCA(n_components=40)
sk_pca_data = sk_pca.fit_transform(sk_test_data.T).T
sk_pca_data = sk_pca_data.reshape(40,64,64)
fig=plt.figure(figsize=(30, 30))
columns = 8 ; rows = 5
for i in range(1, columns*rows +1):
    fig.add_subplot(rows, columns, i)
    plt.imshow(sk_pca_data[i-1],cmap='gray')
    plt.axis('off')
    plt.title(str(i))
plt.show()
# Out:
# (500, 4096)

# %%
# perform kpca from the sklearn library
sk_test_data = train_batch.reshape(500,-1)
print(sk_test_data.shape)
from sklearn.decomposition import KernelPCA
sk_pca = KernelPCA(n_components=40)
sk_pca_data = sk_pca.fit_transform(sk_test_data.T).T
sk_pca_data = sk_pca_data.reshape(40,64,64)
fig=plt.figure(figsize=(30, 30))
columns = 8 ; rows = 5
for i in range(1, columns*rows +1):
    fig.add_subplot(rows, columns, i)
    plt.imshow(sk_pca_data[i-1],cmap='gray')
    plt.axis('off')
    plt.title(str(i))
plt.show()
# Out:
# (500, 4096)

# %%
# perform Fast ICA from the sklearn library
sk_test_data = train_batch.reshape(500,-1)
print(sk_test_data.shape)
from sklearn.decomposition import FastICA
sk_pca = FastICA(n_components=40)
sk_pca_data = sk_pca.fit_transform(sk_test_data.T).T
sk_pca_data = sk_pca_data.reshape(40,64,64)
fig=plt.figure(figsize=(30, 30))
columns = 8 ; rows = 5
for i in range(1, columns*rows +1):
    fig.add_subplot(rows, columns, i)
    plt.imshow(sk_pca_data[i-1],cmap='gray')
    plt.axis('off')
    plt.title(str(i))
plt.show()
# Out:
# (500, 4096)

# %%
! git all-go
# Out:
# [master 8b0563de] s
#  103 files changed, 672 insertions(+), 42 deletions(-)
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/change_deep_ica.mp4
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/0.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/1.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/10.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/11.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/12.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/13.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/14.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/15.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/16.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/17.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/18.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/19.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/2.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/20.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/21.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/22.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/23.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/24.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/25.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/26.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/27.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/28.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/29.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/3.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/30.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/31.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/32.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/33.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/34.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/35.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/7.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/70.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/71.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/72.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/73.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/74.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/75.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/76.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/77.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/78.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/79.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/8.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/80.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/81.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/82.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/83.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/84.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/85.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/86.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/87.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/88.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/89.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/9.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/90.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/91.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/92.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/93.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/94.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/95.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/96.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/97.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/98.png
#  create mode 100644 Understanding_Concepts/review_ICA_PCA/image_data_ica/99.png
# warning: LF will be replaced by CRLF in Understanding_Concepts/review_ICA_PCA/.ipynb_checkpoints/b Deep ICA-checkpoint.ipynb.
# The file will have its original line endings in your working directory.
# warning: LF will be replaced by CRLF in Understanding_Concepts/review_ICA_PCA/b Deep ICA.ipynb.
# The file will have its original line endings in your working directory.
# To https://github.com/JaeDukSeo/Daily-Neural-Network-Practice-2
#    7efe6ada..8b0563de  master -> master
