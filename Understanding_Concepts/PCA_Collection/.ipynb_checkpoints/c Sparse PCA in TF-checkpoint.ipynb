# %%
# import library
import tensorflow as tf
import numpy as np
import sys, os,cv2
from scipy.misc import imread,imresize
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from imgaug import augmenters as iaa
import imgaug as ia
from scipy.ndimage import zoom
from sklearn.utils import shuffle
import matplotlib.animation as animation
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import make_blobs,make_moons,make_swiss_roll

plt.style.use('seaborn')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
# load some data set
n_samples = 4000
X, y = make_moons(n_samples=n_samples, random_state=123,noise=0.1)
X    = X - X.mean(0,keepdims=True)
plt.figure(figsize=(8,6))
plt.scatter(X[y==0, 0], X[y==0, 1], color='red',  alpha=0.5)
plt.scatter(X[y==1, 0], X[y==1, 1], color='blue', alpha=0.5)
plt.title('Current Data Set'); plt.ylabel('y coordinate'); plt.xlabel('x coordinate'); plt.grid(True)
plt.show()
# Out:
# (4000, 2)

# %%
import pywt,sys
import os, random
import numpy as np


class SPC(object):
    
    def __init__(self, number_of_components,max_iter=10, threshold_val=1.5 ):
        self.number_of_components=number_of_components
        self.max_iter = max_iter
        self.threshold_val=threshold_val
    
    def fit(self, X_):

        U, s, V = np.linalg.svd(X_, full_matrices=True)  
        cnt = 0
        self.U = U
        self.W = V.T
        
        def normalize(vector):
            norm=np.linalg.norm(vector)
            if norm>0:
                return vector/norm
            else:
                return vector
            
        while True:
            self.V = pywt.threshold(np.dot(U[:self.number_of_components],X_), self.threshold_val)
            self.U = np.dot(self.V,X_.T)
            self.U = np.array([normalize(u_i) for u_i in self.U])
            
            if cnt%2==0: print("{} out of {} iterations".format(cnt,self.max_iter))
            cnt += 1
            if cnt == self.max_iter:
                self.V = np.array([normalize(v_i) for v_i in self.V])
                break
                
        return self.U,s, self.V, self.W
    
    def transform(self, X_, k=2):
        X_reduced_spca = np.dot(X_, np.dot(self.V[:k].T, self.V[:k]))
        return X_reduced_spca
    
my_spca = SPC(2,max_iter=1000)
U,Sigma,V,W = my_spca.fit(X)
# Out:
# 0 out of 1000 iterations
# 2 out of 1000 iterations
# 4 out of 1000 iterations
# 6 out of 1000 iterations
# 8 out of 1000 iterations
# 10 out of 1000 iterations
# 12 out of 1000 iterations
# 14 out of 1000 iterations
# 16 out of 1000 iterations
# 18 out of 1000 iterations
# 20 out of 1000 iterations
# 22 out of 1000 iterations
# 24 out of 1000 iterations
# 26 out of 1000 iterations
# 28 out of 1000 iterations
# 30 out of 1000 iterations
# 32 out of 1000 iterations
# 34 out of 1000 iterations
# 36 out of 1000 iterations
# 38 out of 1000 iterations
# 40 out of 1000 iterations
# 42 out of 1000 iterations
# 44 out of 1000 iterations
# 46 out of 1000 iterations
# 48 out of 1000 iterations
# 50 out of 1000 iterations
# 52 out of 1000 iterations
# 54 out of 1000 iterations
# 56 out of 1000 iterations
# 58 out of 1000 iterations
# 60 out of 1000 iterations
# 62 out of 1000 iterations
# 64 out of 1000 iterations
# 66 out of 1000 iterations
# 68 out of 1000 iterations
# 70 out of 1000 iterations
# 72 out of 1000 iterations
# 74 out of 1000 iterations
# 76 out of 1000 iterations
# 78 out of 1000 iterations
# 80 out of 1000 iterations
# 82 out of 1000 iterations
# 84 out of 1000 iterations
# 86 out of 1000 iterations
# 88 out of 1000 iterations
# 90 out of 1000 iterations
# 92 out of 1000 iterations
# 94 out of 1000 iterations
# 96 out of 1000 iterations
# 98 out of 1000 iterations
# 100 out of 1000 iterations
# 102 out of 1000 iterations
# 104 out of 1000 iterations
# 106 out of 1000 iterations
# 108 out of 1000 iterations
# 110 out of 1000 iterations
# 112 out of 1000 iterations
# 114 out of 1000 iterations
# 116 out of 1000 iterations
# 118 out of 1000 iterations
# 120 out of 1000 iterations
# 122 out of 1000 iterations
# 124 out of 1000 iterations
# 126 out of 1000 iterations
# 128 out of 1000 iterations
# 130 out of 1000 iterations
# 132 out of 1000 iterations
# 134 out of 1000 iterations
# 136 out of 1000 iterations
# 138 out of 1000 iterations
# 140 out of 1000 iterations
# 142 out of 1000 iterations
# 144 out of 1000 iterations
# 146 out of 1000 iterations
# 148 out of 1000 iterations
# 150 out of 1000 iterations
# 152 out of 1000 iterations
# 154 out of 1000 iterations
# 156 out of 1000 iterations
# 158 out of 1000 iterations
# 160 out of 1000 iterations
# 162 out of 1000 iterations
# 164 out of 1000 iterations
# 166 out of 1000 iterations
# 168 out of 1000 iterations
# 170 out of 1000 iterations
# 172 out of 1000 iterations
# 174 out of 1000 iterations
# 176 out of 1000 iterations
# 178 out of 1000 iterations
# 180 out of 1000 iterations
# 182 out of 1000 iterations
# 184 out of 1000 iterations
# 186 out of 1000 iterations
# 188 out of 1000 iterations
# 190 out of 1000 iterations
# 192 out of 1000 iterations
# 194 out of 1000 iterations
# 196 out of 1000 iterations
# 198 out of 1000 iterations
# 200 out of 1000 iterations
# 202 out of 1000 iterations
# 204 out of 1000 iterations
# 206 out of 1000 iterations
# 208 out of 1000 iterations
# 210 out of 1000 iterations
# 212 out of 1000 iterations
# 214 out of 1000 iterations
# 216 out of 1000 iterations
# 218 out of 1000 iterations
# 220 out of 1000 iterations
# 222 out of 1000 iterations
# 224 out of 1000 iterations
# 226 out of 1000 iterations
# 228 out of 1000 iterations
# 230 out of 1000 iterations
# 232 out of 1000 iterations
# 234 out of 1000 iterations
# 236 out of 1000 iterations
# 238 out of 1000 iterations
# 240 out of 1000 iterations
# 242 out of 1000 iterations
# 244 out of 1000 iterations
# 246 out of 1000 iterations
# 248 out of 1000 iterations
# 250 out of 1000 iterations
# 252 out of 1000 iterations
# 254 out of 1000 iterations
# 256 out of 1000 iterations
# 258 out of 1000 iterations
# 260 out of 1000 iterations
# 262 out of 1000 iterations
# 264 out of 1000 iterations
# 266 out of 1000 iterations
# 268 out of 1000 iterations
# 270 out of 1000 iterations
# 272 out of 1000 iterations
# 274 out of 1000 iterations
# 276 out of 1000 iterations
# 278 out of 1000 iterations
# 280 out of 1000 iterations
# 282 out of 1000 iterations
# 284 out of 1000 iterations
# 286 out of 1000 iterations
# 288 out of 1000 iterations
# 290 out of 1000 iterations
# 292 out of 1000 iterations
# 294 out of 1000 iterations
# 296 out of 1000 iterations
# 298 out of 1000 iterations
# 300 out of 1000 iterations
# 302 out of 1000 iterations
# 304 out of 1000 iterations
# 306 out of 1000 iterations
# 308 out of 1000 iterations
# 310 out of 1000 iterations
# 312 out of 1000 iterations
# 314 out of 1000 iterations
# 316 out of 1000 iterations
# 318 out of 1000 iterations
# 320 out of 1000 iterations
# 322 out of 1000 iterations
# 324 out of 1000 iterations
# 326 out of 1000 iterations
# 328 out of 1000 iterations
# 330 out of 1000 iterations
# 332 out of 1000 iterations
# 334 out of 1000 iterations
# 336 out of 1000 iterations
# 338 out of 1000 iterations
# 340 out of 1000 iterations
# 342 out of 1000 iterations
# 344 out of 1000 iterations
# 346 out of 1000 iterations
# 348 out of 1000 iterations
# 350 out of 1000 iterations
# 352 out of 1000 iterations
# 354 out of 1000 iterations
# 356 out of 1000 iterations
# 358 out of 1000 iterations
# 360 out of 1000 iterations
# 362 out of 1000 iterations
# 364 out of 1000 iterations
# 366 out of 1000 iterations
# 368 out of 1000 iterations
# 370 out of 1000 iterations
# 372 out of 1000 iterations
# 374 out of 1000 iterations
# 376 out of 1000 iterations
# 378 out of 1000 iterations
# 380 out of 1000 iterations
# 382 out of 1000 iterations
# 384 out of 1000 iterations
# 386 out of 1000 iterations
# 388 out of 1000 iterations
# 390 out of 1000 iterations
# 392 out of 1000 iterations
# 394 out of 1000 iterations
# 396 out of 1000 iterations
# 398 out of 1000 iterations
# 400 out of 1000 iterations
# 402 out of 1000 iterations
# 404 out of 1000 iterations
# 406 out of 1000 iterations
# 408 out of 1000 iterations
# 410 out of 1000 iterations
# 412 out of 1000 iterations
# 414 out of 1000 iterations
# 416 out of 1000 iterations
# 418 out of 1000 iterations
# 420 out of 1000 iterations
# 422 out of 1000 iterations
# 424 out of 1000 iterations
# 426 out of 1000 iterations
# 428 out of 1000 iterations
# 430 out of 1000 iterations
# 432 out of 1000 iterations
# 434 out of 1000 iterations
# 436 out of 1000 iterations
# 438 out of 1000 iterations
# 440 out of 1000 iterations
# 442 out of 1000 iterations
# 444 out of 1000 iterations
# 446 out of 1000 iterations
# 448 out of 1000 iterations
# 450 out of 1000 iterations
# 452 out of 1000 iterations
# 454 out of 1000 iterations
# 456 out of 1000 iterations
# 458 out of 1000 iterations
# 460 out of 1000 iterations
# 462 out of 1000 iterations
# 464 out of 1000 iterations
# 466 out of 1000 iterations
# 468 out of 1000 iterations
# 470 out of 1000 iterations
# 472 out of 1000 iterations
# 474 out of 1000 iterations
# 476 out of 1000 iterations
# 478 out of 1000 iterations
# 480 out of 1000 iterations
# 482 out of 1000 iterations
# 484 out of 1000 iterations
# 486 out of 1000 iterations
# 488 out of 1000 iterations
# 490 out of 1000 iterations
# 492 out of 1000 iterations
# 494 out of 1000 iterations
# 496 out of 1000 iterations
# 498 out of 1000 iterations
# 500 out of 1000 iterations
# 502 out of 1000 iterations
# 504 out of 1000 iterations
# 506 out of 1000 iterations
# 508 out of 1000 iterations
# 510 out of 1000 iterations
# 512 out of 1000 iterations
# 514 out of 1000 iterations
# 516 out of 1000 iterations
# 518 out of 1000 iterations
# 520 out of 1000 iterations
# 522 out of 1000 iterations
# 524 out of 1000 iterations
# 526 out of 1000 iterations
# 528 out of 1000 iterations
# 530 out of 1000 iterations
# 532 out of 1000 iterations
# 534 out of 1000 iterations
# 536 out of 1000 iterations
# 538 out of 1000 iterations
# 540 out of 1000 iterations
# 542 out of 1000 iterations
# 544 out of 1000 iterations
# 546 out of 1000 iterations
# 548 out of 1000 iterations
# 550 out of 1000 iterations
# 552 out of 1000 iterations
# 554 out of 1000 iterations
# 556 out of 1000 iterations
# 558 out of 1000 iterations
# 560 out of 1000 iterations
# 562 out of 1000 iterations
# 564 out of 1000 iterations
# 566 out of 1000 iterations
# 568 out of 1000 iterations
# 570 out of 1000 iterations
# 572 out of 1000 iterations
# 574 out of 1000 iterations
# 576 out of 1000 iterations
# 578 out of 1000 iterations
# 580 out of 1000 iterations
# 582 out of 1000 iterations
# 584 out of 1000 iterations
# 586 out of 1000 iterations
# 588 out of 1000 iterations
# 590 out of 1000 iterations
# 592 out of 1000 iterations
# 594 out of 1000 iterations
# 596 out of 1000 iterations
# 598 out of 1000 iterations
# 600 out of 1000 iterations
# 602 out of 1000 iterations
# 604 out of 1000 iterations
# 606 out of 1000 iterations
# 608 out of 1000 iterations
# 610 out of 1000 iterations
# 612 out of 1000 iterations
# 614 out of 1000 iterations
# 616 out of 1000 iterations
# 618 out of 1000 iterations
# 620 out of 1000 iterations
# 622 out of 1000 iterations
# 624 out of 1000 iterations
# 626 out of 1000 iterations
# 628 out of 1000 iterations
# 630 out of 1000 iterations
# 632 out of 1000 iterations
# 634 out of 1000 iterations
# 636 out of 1000 iterations
# 638 out of 1000 iterations
# 640 out of 1000 iterations
# 642 out of 1000 iterations
# 644 out of 1000 iterations
# 646 out of 1000 iterations
# 648 out of 1000 iterations
# 650 out of 1000 iterations
# 652 out of 1000 iterations
# 654 out of 1000 iterations
# 656 out of 1000 iterations
# 658 out of 1000 iterations
# 660 out of 1000 iterations
# 662 out of 1000 iterations
# 664 out of 1000 iterations
# 666 out of 1000 iterations
# 668 out of 1000 iterations
# 670 out of 1000 iterations
# 672 out of 1000 iterations
# 674 out of 1000 iterations
# 676 out of 1000 iterations
# 678 out of 1000 iterations
# 680 out of 1000 iterations
# 682 out of 1000 iterations
# 684 out of 1000 iterations
# 686 out of 1000 iterations
# 688 out of 1000 iterations
# 690 out of 1000 iterations
# 692 out of 1000 iterations
# 694 out of 1000 iterations
# 696 out of 1000 iterations
# 698 out of 1000 iterations
# 700 out of 1000 iterations
# 702 out of 1000 iterations
# 704 out of 1000 iterations
# 706 out of 1000 iterations
# 708 out of 1000 iterations
# 710 out of 1000 iterations
# 712 out of 1000 iterations
# 714 out of 1000 iterations
# 716 out of 1000 iterations
# 718 out of 1000 iterations
# 720 out of 1000 iterations
# 722 out of 1000 iterations
# 724 out of 1000 iterations
# 726 out of 1000 iterations
# 728 out of 1000 iterations
# 730 out of 1000 iterations
# 732 out of 1000 iterations
# 734 out of 1000 iterations
# 736 out of 1000 iterations
# 738 out of 1000 iterations
# 740 out of 1000 iterations
# 742 out of 1000 iterations
# 744 out of 1000 iterations
# 746 out of 1000 iterations
# 748 out of 1000 iterations
# 750 out of 1000 iterations
# 752 out of 1000 iterations
# 754 out of 1000 iterations
# 756 out of 1000 iterations
# 758 out of 1000 iterations
# 760 out of 1000 iterations
# 762 out of 1000 iterations
# 764 out of 1000 iterations
# 766 out of 1000 iterations
# 768 out of 1000 iterations
# 770 out of 1000 iterations
# 772 out of 1000 iterations
# 774 out of 1000 iterations
# 776 out of 1000 iterations
# 778 out of 1000 iterations
# 780 out of 1000 iterations
# 782 out of 1000 iterations
# 784 out of 1000 iterations
# 786 out of 1000 iterations
# 788 out of 1000 iterations
# 790 out of 1000 iterations
# 792 out of 1000 iterations
# 794 out of 1000 iterations
# 796 out of 1000 iterations
# 798 out of 1000 iterations
# 800 out of 1000 iterations
# 802 out of 1000 iterations
# 804 out of 1000 iterations
# 806 out of 1000 iterations
# 808 out of 1000 iterations
# 810 out of 1000 iterations
# 812 out of 1000 iterations
# 814 out of 1000 iterations
# 816 out of 1000 iterations
# 818 out of 1000 iterations
# 820 out of 1000 iterations
# 822 out of 1000 iterations
# 824 out of 1000 iterations
# 826 out of 1000 iterations
# 828 out of 1000 iterations
# 830 out of 1000 iterations
# 832 out of 1000 iterations
# 834 out of 1000 iterations
# 836 out of 1000 iterations
# 838 out of 1000 iterations
# 840 out of 1000 iterations
# 842 out of 1000 iterations
# 844 out of 1000 iterations
# 846 out of 1000 iterations
# 848 out of 1000 iterations
# 850 out of 1000 iterations
# 852 out of 1000 iterations
# 854 out of 1000 iterations
# 856 out of 1000 iterations
# 858 out of 1000 iterations
# 860 out of 1000 iterations
# 862 out of 1000 iterations
# 864 out of 1000 iterations
# 866 out of 1000 iterations
# 868 out of 1000 iterations
# 870 out of 1000 iterations
# 872 out of 1000 iterations
# 874 out of 1000 iterations
# 876 out of 1000 iterations
# 878 out of 1000 iterations
# 880 out of 1000 iterations
# 882 out of 1000 iterations
# 884 out of 1000 iterations
# 886 out of 1000 iterations
# 888 out of 1000 iterations
# 890 out of 1000 iterations
# 892 out of 1000 iterations
# 894 out of 1000 iterations
# 896 out of 1000 iterations
# 898 out of 1000 iterations
# 900 out of 1000 iterations
# 902 out of 1000 iterations
# 904 out of 1000 iterations
# 906 out of 1000 iterations
# 908 out of 1000 iterations
# 910 out of 1000 iterations
# 912 out of 1000 iterations
# 914 out of 1000 iterations
# 916 out of 1000 iterations
# 918 out of 1000 iterations
# 920 out of 1000 iterations
# 922 out of 1000 iterations
# 924 out of 1000 iterations
# 926 out of 1000 iterations
# 928 out of 1000 iterations
# 930 out of 1000 iterations
# 932 out of 1000 iterations
# 934 out of 1000 iterations
# 936 out of 1000 iterations
# 938 out of 1000 iterations
# 940 out of 1000 iterations
# 942 out of 1000 iterations
# 944 out of 1000 iterations
# 946 out of 1000 iterations
# 948 out of 1000 iterations
# 950 out of 1000 iterations
# 952 out of 1000 iterations
# 954 out of 1000 iterations
# 956 out of 1000 iterations
# 958 out of 1000 iterations
# 960 out of 1000 iterations
# 962 out of 1000 iterations
# 964 out of 1000 iterations
# 966 out of 1000 iterations
# 968 out of 1000 iterations
# 970 out of 1000 iterations
# 972 out of 1000 iterations
# 974 out of 1000 iterations
# 976 out of 1000 iterations
# 978 out of 1000 iterations
# 980 out of 1000 iterations
# 982 out of 1000 iterations
# 984 out of 1000 iterations
# 986 out of 1000 iterations
# 988 out of 1000 iterations
# 990 out of 1000 iterations
# 992 out of 1000 iterations
# 994 out of 1000 iterations
# 996 out of 1000 iterations
# 998 out of 1000 iterations

# %%
UT = U.T @ np.diag(Sigma)
print(UT.shape)
plt.figure(figsize=(8,6))
plt.scatter(UT[y==0, 0], UT[y==0, 1], color='red',  alpha=0.5)
plt.scatter(UT[y==1, 0], UT[y==1, 1], color='blue', alpha=0.5)
plt.title('Current Data Set'); plt.ylabel('y coordinate'); plt.xlabel('x coordinate'); plt.grid(True)
plt.show()
# Out:
# (4000, 2)

# %%
temp = np.asarray([
    [1,2,3,4,5]
])
print(np.linalg.norm(temp))
print(np.sqrt( (temp ** 2).sum()) )
# Out:
# 7.416198487095663
# 7.416198487095663

# %% [markdown]
# # Reference
# 1. tf.set_random_seed | TensorFlow. (2018). TensorFlow. Retrieved 28 October 2018, from https://www.tensorflow.org/api_docs/python/tf/set_random_seed
# 2. Comparing different hierarchical linkage methods on toy datasets — scikit-learn 0.20.0 documentation. (2018). Scikit-learn.org. Retrieved 28 October 2018, from http://scikit-learn.org/stable/auto_examples/cluster/plot_linkage_comparison.html#sphx-glr-auto-examples-cluster-plot-linkage-comparison-py
# 3. VanderPlas, J. (2018). Multiple Subplots | Python Data Science Handbook. Jakevdp.github.io. Retrieved 28 October 2018, from https://jakevdp.github.io/PythonDataScienceHandbook/04.08-multiple-subplots.html
# 4. object, M. (2018). Matplotlib returning a plot object. Stack Overflow. Retrieved 28 October 2018, from https://stackoverflow.com/questions/43925337/matplotlib-returning-a-plot-object
# 5. Plot randomly generated classification dataset — scikit-learn 0.20.0 documentation. (2018). Scikit-learn.org. Retrieved 28 October 2018, from http://scikit-learn.org/stable/auto_examples/datasets/plot_random_dataset.html#sphx-glr-auto-examples-datasets-plot-random-dataset-py
# 6. 5. Dataset loading utilities — scikit-learn 0.20.0 documentation. (2018). Scikit-learn.org. Retrieved 28 October 2018, from http://scikit-learn.org/stable/datasets/index.html
# 7. mplot3d tutorial — Matplotlib 2.0.2 documentation. (2018). Matplotlib.org. Retrieved 28 October 2018, from https://matplotlib.org/mpl_toolkits/mplot3d/tutorial.html
# 8. matplotlib, H. (2018). How to plot vectors in python using matplotlib. Stack Overflow. Retrieved 28 October 2018, from https://stackoverflow.com/questions/42281966/how-to-plot-vectors-in-python-using-matplotlib
# 9. arrow, M. (2018). Matplotlib legend for an arrow. Stack Overflow. Retrieved 28 October 2018, from https://stackoverflow.com/questions/22348229/matplotlib-legend-for-an-arrow
# 10. plt colors - Google Search. (2018). Google.ca. Retrieved 28 October 2018, from https://www.google.ca/search?q=plt+colors&rlz=1C1CHBF_enCA771CA771&oq=plt+colors&aqs=chrome..69i57j0l5.1038j0j7&sourceid=chrome&ie=UTF-8
# 11. Brownlee, J. (2018). A Gentle Introduction to Singular-Value Decomposition for Machine Learning. Machine Learning Mastery. Retrieved 28 October 2018, from https://machinelearningmastery.com/singular-value-decomposition-for-machine-learning/
# 12. https://www.quora.com/Why-do-we-need-to-center-the-data-for-Principle-Components-Analysis
# 13. Distance Matrix Vectorization Trick – Manifold Blog – Medium. (2016). Medium. Retrieved 29 October 2018, from https://medium.com/dataholiks-distillery/l2-distance-matrix-vectorization-trick-26aa3247ac6c
# 14. (pdist), H. (2018). How does condensed distance matrix work? (pdist). Stack Overflow. Retrieved 29 October 2018, from https://stackoverflow.com/questions/13079563/how-does-condensed-distance-matrix-work-pdist
# 15. aboyker/easyspc. (2018). GitHub. Retrieved 29 October 2018, from https://github.com/aboyker/easyspc/blob/master/build/lib/easyspc/__init__.py
# 16. numpy.linalg.norm — NumPy v1.15 Manual. (2018). Docs.scipy.org. Retrieved 29 October 2018, from https://docs.scipy.org/doc/numpy-1.15.1/reference/generated/numpy.linalg.norm.html
# 17. matrix, C. (2018). Calculating norm of columns as vectors in a matrix. Stack Overflow. Retrieved 29 October 2018, from https://stackoverflow.com/questions/15725611/calculating-norm-of-columns-as-vectors-in-a-matrixa
# 18.
