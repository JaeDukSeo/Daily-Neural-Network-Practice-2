# %%
# import library
import tensorflow as tf
import numpy as np
import sys, os,cv2
from scipy.misc import imread,imresize
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from imgaug import augmenters as iaa
import imgaug as ia
from scipy.ndimage import zoom
from sklearn.utils import shuffle
import matplotlib.animation as animation
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import make_blobs,make_moons,make_swiss_roll

plt.style.use('seaborn')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
# load some data set
n_samples = 4000
X, y = make_moons(n_samples=n_samples, random_state=123,noise=0.1)
X = (X - X.min(0,keepdims=True)) / (X.max(0,keepdims=True) - X.min(0,keepdims=True))
X = X - X.mean(0,keepdims=True)
plt.figure(figsize=(8,6))
plt.scatter(X[y==0, 0], X[y==0, 1], color='red',  alpha=0.5)
plt.scatter(X[y==1, 0], X[y==1, 1], color='blue', alpha=0.5)
plt.title('Current Data Set'); plt.ylabel('y coordinate'); plt.xlabel('x coordinate'); plt.grid(True)
plt.show()

# %%
# Do EVD to see the projection matrix
cov        = X.T @ X /(X.shape[0] - 1)
val,vec    = np.linalg.eigh(cov)
idx        = np.argsort(val)[::-1]; val = val[idx]; vec = vec[:,idx]
project_X  = X   @ vec;                      project_V  = vec.T @ vec
revert_X   = project_X @ np.linalg.inv(vec) ;revertedV  = project_V @ np.linalg.inv(vec).T

plt.figure(figsize=(15,5)); 

plt.subplot(131); 
plt.scatter(X[y==0, 0], X[y==0, 1], color='red',  alpha=0.5)
plt.scatter(X[y==1, 0], X[y==1, 1], color='blue', alpha=0.5)
pca11=plt.arrow   (0, 0, *vec[:,0] * val[0], head_width=0.05, head_length=0.05,color='Green',  label='First PC')
pca12=plt.arrow   (0, 0, *vec[:,1] * val[1], head_width=0.05, head_length=0.05,color='magenta',label='Second PC')
plt.grid(True); 

plt.subplot(132); 
plt.scatter(project_X[y==0, 0], project_X[y==0, 1], color='red',  alpha=0.5)
plt.scatter(project_X[y==1, 0], project_X[y==1, 1], color='blue', alpha=0.5)
pca21=plt.arrow   (0, 0, *project_V[:,0] * val[0], head_width=0.05, head_length=0.05,color='Green',  label='First PC')
pca22=plt.arrow   (0, 0, *project_V[:,1] * val[1], head_width=0.05, head_length=0.05,color='magenta',label='Second PC')
plt.grid(True); 

plt.subplot(133); 
plt.scatter(revert_X[y==0, 0], revert_X[y==0, 1], color='red',  alpha=0.5)
plt.scatter(revert_X[y==1, 0], revert_X[y==1, 1], color='blue', alpha=0.5)
pca21=plt.arrow   (0, 0, *revertedV[:,0] * val[0], head_width=0.05, head_length=0.05,color='Green',  label='First PC')
pca22=plt.arrow   (0, 0, *revertedV[:,1] * val[1], head_width=0.05, head_length=0.05,color='magenta',label='Second PC')
plt.grid(True); 

plt.show()

# %%
# perform D reduction
cov        = X.T @ X /(X.shape[0] - 1)
val,vec    = np.linalg.eigh(cov)
idx        = np.argsort(val)[::-1]; val = val[idx]; vec = vec[:,idx]

vec_reduced= np.zeros_like(vec)
vec_reduced[:,:1] = vec[:,:1]
val_reduced= val.copy()
val_reduced[-1:]= 0

project_X  = X   @ vec_reduced;                      project_V  = vec_reduced.T @ vec_reduced
revert_X   = project_X @ np.linalg.inv(vec_reduced+0.0001) ;revertedV  = project_V.T @ np.linalg.inv(vec_reduced+0.0001)

plt.figure(figsize=(15,5)); 

plt.subplot(131); 
plt.scatter(X[y==0, 0], X[y==0, 1], color='red',  alpha=0.5)
plt.scatter(X[y==1, 0], X[y==1, 1], color='blue', alpha=0.5)
pca11=plt.arrow   (0, 0, *vec[:,0] * val[0], head_width=0.05, head_length=0.05,color='Green',  label='First PC')
pca12=plt.arrow   (0, 0, *vec[:,1] * val[1], head_width=0.05, head_length=0.05,color='magenta',label='Second PC')
plt.grid(True); 

plt.subplot(132); 
plt.scatter(project_X[y==0, 0], project_X[y==0, 1], color='red',  alpha=0.5)
plt.scatter(project_X[y==1, 0], project_X[y==1, 1], color='blue', alpha=0.5)
pca21=plt.arrow   (0, 0, *project_V[:,0] * val_reduced[0], head_width=0.05, head_length=0.05,color='Green',  label='First PC')
pca22=plt.arrow   (0, 0, *project_V[:,1] * val_reduced[1], head_width=0.05, head_length=0.05,color='magenta',label='Second PC')
plt.grid(True); 

plt.subplot(133); 
plt.scatter(revert_X[y==0, 0], revert_X[y==0, 1], color='red',  alpha=0.5)
plt.scatter(revert_X[y==1, 0], revert_X[y==1, 1], color='blue', alpha=0.5)
pca21=plt.arrow   (0, 0, *revertedV[:,0] * val_reduced[0], head_width=0.05, head_length=0.05,color='Green',  label='First PC')
pca22=plt.arrow   (0, 0, *revertedV[:,1] * val_reduced[1], head_width=0.05, head_length=0.05,color='magenta',label='Second PC')
plt.grid(True); 

plt.show()

# %%
# do the reduction but in a different way
cov        = X.T @ X /(X.shape[0] - 1)
val,vec    = np.linalg.eigh(cov)
idx        = np.argsort(val)[::-1]; val = val[idx]; vec = vec[:,idx]
vec        = np.exp(vec)

project_X    = X   @ vec;                      project_V  = vec.T @ vec
# inversed_vec = np.linalg.inv(vec)
# inversed_vec = inversed_vec + inversed_vec.mean(0,keepdims=True)
# revert_X   = project_X @ inversed_vec ;revertedV  = project_V.T @ inversed_vec

plt.figure(figsize=(15,5)); 

plt.subplot(131); 
plt.scatter(X[y==0, 0], X[y==0, 1], color='red',  alpha=0.5)
plt.scatter(X[y==1, 0], X[y==1, 1], color='blue', alpha=0.5)
pca11=plt.arrow   (0, 0, *vec[:,0] * val[0], head_width=0.05, head_length=0.05,color='Green',  label='First PC')
pca12=plt.arrow   (0, 0, *vec[:,1] * val[1], head_width=0.05, head_length=0.05,color='magenta',label='Second PC')
plt.grid(True); 

plt.subplot(132); 
plt.scatter(project_X[y==0, 0], project_X[y==0, 1], color='red',  alpha=0.5)
plt.scatter(project_X[y==1, 0], project_X[y==1, 1], color='blue', alpha=0.5)
pca21=plt.arrow   (0, 0, *project_V[:,0] * val_reduced[0], head_width=0.05, head_length=0.05,color='Green',  label='First PC')
pca22=plt.arrow   (0, 0, *project_V[:,1] * val_reduced[1], head_width=0.05, head_length=0.05,color='magenta',label='Second PC')
plt.grid(True); 

# plt.subplot(133); 
# plt.scatter(revert_X[y==0, 0], revert_X[y==0, 1], color='red',  alpha=0.5)
# plt.scatter(revert_X[y==1, 0], revert_X[y==1, 1], color='blue', alpha=0.5)
# pca21=plt.arrow   (0, 0, *revertedV[:,0] * val_reduced[0], head_width=0.05, head_length=0.05,color='Green',  label='First PC')
# pca22=plt.arrow   (0, 0, *revertedV[:,1] * val_reduced[1], head_width=0.05, head_length=0.05,color='magenta',label='Second PC')
# plt.grid(True); 

plt.show()
# Out:
# [[0.50228965 0.48424613]
#  [2.06506554 0.50228965]]

# %%
# Do EVD to see the projection matrix
cov        = X.T @ X /(X.shape[0] - 1)
val,vec    = np.linalg.eigh(cov)
idx        = np.argsort(val)[::-1]; val = val[idx]; vec = vec[:,idx]
project_X  = X   @ vec;                      project_V  = vec.T @ vec

plt.figure(figsize=(15,5)); 

plt.subplot(141); 
plt.scatter(X[y==0, 0], X[y==0, 1], color='red',  alpha=0.5)
plt.scatter(X[y==1, 0], X[y==1, 1], color='blue', alpha=0.5)
pca11=plt.arrow   (0, 0, *vec[:,0] * val[0], head_width=0.05, head_length=0.05,color='Green',  label='First PC')
pca12=plt.arrow   (0, 0, *vec[:,1] * val[1], head_width=0.05, head_length=0.05,color='magenta',label='Second PC')
plt.grid(True); 

plt.subplot(142); 
plt.scatter(project_X[y==0, 0], project_X[y==0, 1], color='red',  alpha=0.5)
plt.scatter(project_X[y==1, 0], project_X[y==1, 1], color='blue', alpha=0.5)
pca21=plt.arrow   (0, 0, *project_V[:,0] * val[0], head_width=0.05, head_length=0.05,color='Green',  label='First PC')
pca22=plt.arrow   (0, 0, *project_V[:,1] * val[1], head_width=0.05, head_length=0.05,color='magenta',label='Second PC')
plt.grid(True); 

inverse  = np.linalg.inv(vec)
inverse  = inverse - inverse.mean(0,keepdims=True) 
revert_X   = project_X @ inverse ;revertedV  = project_V @ inverse.T

plt.subplot(143); 
plt.scatter(revert_X[y==0, 0], revert_X[y==0, 1], color='red',  alpha=0.5)
plt.scatter(revert_X[y==1, 0], revert_X[y==1, 1], color='blue', alpha=0.5)
pca21=plt.arrow   (0, 0, *revertedV[:,0] * val[0], head_width=0.05, head_length=0.05,color='Green',  label='First PC')
pca22=plt.arrow   (0, 0, *revertedV[:,1] * val[1], head_width=0.05, head_length=0.05,color='magenta',label='Second PC')
plt.grid(True); 

inverse  = np.linalg.inv(vec)
inverse  = inverse - inverse*inverse.std(0,keepdims=True)
revert_X   = project_X @ inverse ;revertedV  = project_V @ inverse.T

plt.subplot(144); 
plt.scatter(revert_X[y==0, 0], revert_X[y==0, 1], color='red',  alpha=0.5)
plt.scatter(revert_X[y==1, 0], revert_X[y==1, 1], color='blue', alpha=0.5)
pca21=plt.arrow   (0, 0, *revertedV[:,0] * val[0], head_width=0.05, head_length=0.05,color='Green',  label='First PC')
pca22=plt.arrow   (0, 0, *revertedV[:,1] * val[1], head_width=0.05, head_length=0.05,color='magenta',label='Second PC')
plt.grid(True); 

plt.show()

# %%
# kernel PCA
gamma = 100
sq_x  = -2 * X @ X.T + np.sum(X**2,1) + np.sum(X**2,1,keepdims=True)
K     = np.exp(-gamma * sq_x)
N     = K.shape[0]
one_n = np.ones((N,N)) / N
K2    = K - one_n.dot(K) - K.dot(one_n) + one_n.dot(K).dot(one_n)
eigvals, eigvecs = np.linalg.eigh(K2)

# %%
new_pc = eigvecs[:,-2:]

plt.figure(figsize=(15,5)); 

plt.subplot(121); 
plt.scatter(X[y==0, 0], X[y==0, 1], color='red',  alpha=0.5)
plt.scatter(X[y==1, 0], X[y==1, 1], color='blue', alpha=0.5)
pca11=plt.arrow   (0, 0, *vec[:,0] * val[0], head_width=0.05, head_length=0.05,color='Green',  label='First PC')
pca12=plt.arrow   (0, 0, *vec[:,1] * val[1], head_width=0.05, head_length=0.05,color='magenta',label='Second PC')
plt.grid(True); 

new_pc_cen = new_pc - new_pc.mean(0,keepdims=True)
cov        = new_pc_cen.T @ new_pc_cen /(new_pc_cen.shape[0] - 1)
val,vec    = np.linalg.eigh(cov)

plt.subplot(122); 
plt.scatter(new_pc[y==0, 0], new_pc[y==0, 1], color='red',  alpha=0.5)
plt.scatter(new_pc[y==1, 0], new_pc[y==1, 1], color='blue', alpha=0.5)
pca21=plt.arrow   (0, 0, *vec[:,0] * val[0], head_width=0.005, head_length=0.005,color='Green',  label='First PC')
pca22=plt.arrow   (0, 0, *vec[:,1] * val[1], head_width=0.005, head_length=0.005,color='magenta',label='Second PC')
plt.grid(True); 

plt.show()

# %%
# Spase PCA
import pywt

class SPC(object):
    
    def __init__(self, number_of_components,max_iter=10, threshold_val=1.5 ):
        
        
        """Initialize the SPC object
        
        Positional arguments:
        number_of_components -- the number of sparse principal components 
        to compute, must be between 1 and p (total number of features)
        
        Keyword argument:
        max_iter -- the number of iterations to perform (default=10)
        threshold_val -- value of the lambda regularisation 
        parameter (default=10)
        """
        self.number_of_components=number_of_components
        self.max_iter=max_iter
        self.threshold_val=threshold_val
    
    def fit(self, X_):
        """learn the sparse pc of a data matrix, return sparse estimates
        of the left and right singular vectors (U and V respectively) 
        as well as the standard principal components loading matrix W
    
        Positional arguments:
        X_ -- training data matrix, as numpy ndarray
        
        """ 
        print("computing sparse principal components...")
        print("computing SVD of data matrix...")
        U, s, V = np.linalg.svd(X_, full_matrices=True)  
        cnt = 0
        self.U = U
        self.W = V.T
        def normalize(vector):
            norm=np.linalg.norm(vector)
            if norm>0:
                return vector/norm
            else:
                return vector
        print("starting iterations...")
        while True:
           
            self.V = pywt.threshold(np.dot(U[:self.number_of_components],X_), self.threshold_val)
            self.U = np.dot(self.V,X_.T)
            self.U = np.array([normalize(u_i) for u_i in self.U])
            if cnt%2==0:
                print("{} out of {} iterations".format(cnt,self.max_iter))
            cnt += 1
            if cnt == self.max_iter:
                self.V = np.array([normalize(v_i) for v_i in self.V])
                break
        print("...finish")
        return self.U, self.V, self.W
    
    def transform(self, X_, k=2):
        X_reduced_spca     = np.dot(X_, np.dot(self.V[:k].T, self.V[:k]))
        return X_reduced_spca
my_spca  = SPC(2,3000,0.1)
my_spca.fit(X)
# Out:
# computing sparse principal components...
# computing SVD of data matrix...
# starting iterations...
# 0 out of 3000 iterations
# 2 out of 3000 iterations
# 4 out of 3000 iterations
# 6 out of 3000 iterations
# 8 out of 3000 iterations
# 10 out of 3000 iterations
# 12 out of 3000 iterations
# 14 out of 3000 iterations
# 16 out of 3000 iterations
# 18 out of 3000 iterations
# 20 out of 3000 iterations
# 22 out of 3000 iterations
# 24 out of 3000 iterations
# 26 out of 3000 iterations
# 28 out of 3000 iterations
# 30 out of 3000 iterations
# 32 out of 3000 iterations
# 34 out of 3000 iterations
# 36 out of 3000 iterations
# 38 out of 3000 iterations
# 40 out of 3000 iterations
# 42 out of 3000 iterations
# 44 out of 3000 iterations
# 46 out of 3000 iterations
# 48 out of 3000 iterations
# 50 out of 3000 iterations
# 52 out of 3000 iterations
# 54 out of 3000 iterations
# 56 out of 3000 iterations
# 58 out of 3000 iterations
# 60 out of 3000 iterations
# 62 out of 3000 iterations
# 64 out of 3000 iterations
# 66 out of 3000 iterations
# 68 out of 3000 iterations
# 70 out of 3000 iterations
# 72 out of 3000 iterations
# 74 out of 3000 iterations
# 76 out of 3000 iterations
# 78 out of 3000 iterations
# 80 out of 3000 iterations
# 82 out of 3000 iterations
# 84 out of 3000 iterations
# 86 out of 3000 iterations
# 88 out of 3000 iterations
# 90 out of 3000 iterations
# 92 out of 3000 iterations
# 94 out of 3000 iterations
# 96 out of 3000 iterations
# 98 out of 3000 iterations
# 100 out of 3000 iterations
# 102 out of 3000 iterations
# 104 out of 3000 iterations
# 106 out of 3000 iterations
# 108 out of 3000 iterations
# 110 out of 3000 iterations
# 112 out of 3000 iterations
# 114 out of 3000 iterations
# 116 out of 3000 iterations
# 118 out of 3000 iterations
# 120 out of 3000 iterations
# 122 out of 3000 iterations
# 124 out of 3000 iterations
# 126 out of 3000 iterations
# 128 out of 3000 iterations
# 130 out of 3000 iterations
# 132 out of 3000 iterations
# 134 out of 3000 iterations
# 136 out of 3000 iterations
# 138 out of 3000 iterations
# 140 out of 3000 iterations
# 142 out of 3000 iterations
# 144 out of 3000 iterations
# 146 out of 3000 iterations
# 148 out of 3000 iterations
# 150 out of 3000 iterations
# 152 out of 3000 iterations
# 154 out of 3000 iterations
# 156 out of 3000 iterations
# 158 out of 3000 iterations
# 160 out of 3000 iterations
# 162 out of 3000 iterations
# 164 out of 3000 iterations
# 166 out of 3000 iterations
# 168 out of 3000 iterations
# 170 out of 3000 iterations
# 172 out of 3000 iterations
# 174 out of 3000 iterations
# 176 out of 3000 iterations
# 178 out of 3000 iterations
# 180 out of 3000 iterations
# 182 out of 3000 iterations
# 184 out of 3000 iterations
# 186 out of 3000 iterations
# 188 out of 3000 iterations
# 190 out of 3000 iterations
# 192 out of 3000 iterations
# 194 out of 3000 iterations
# 196 out of 3000 iterations
# 198 out of 3000 iterations
# 200 out of 3000 iterations
# 202 out of 3000 iterations
# 204 out of 3000 iterations
# 206 out of 3000 iterations
# 208 out of 3000 iterations
# 210 out of 3000 iterations
# 212 out of 3000 iterations
# 214 out of 3000 iterations
# 216 out of 3000 iterations
# 218 out of 3000 iterations
# 220 out of 3000 iterations
# 222 out of 3000 iterations
# 224 out of 3000 iterations
# 226 out of 3000 iterations
# 228 out of 3000 iterations
# 230 out of 3000 iterations
# 232 out of 3000 iterations
# 234 out of 3000 iterations
# 236 out of 3000 iterations
# 238 out of 3000 iterations
# 240 out of 3000 iterations
# 242 out of 3000 iterations
# 244 out of 3000 iterations
# 246 out of 3000 iterations
# 248 out of 3000 iterations
# 250 out of 3000 iterations
# 252 out of 3000 iterations
# 254 out of 3000 iterations
# 256 out of 3000 iterations
# 258 out of 3000 iterations
# 260 out of 3000 iterations
# 262 out of 3000 iterations
# 264 out of 3000 iterations
# 266 out of 3000 iterations
# 268 out of 3000 iterations
# 270 out of 3000 iterations
# 272 out of 3000 iterations
# 274 out of 3000 iterations
# 276 out of 3000 iterations
# 278 out of 3000 iterations
# 280 out of 3000 iterations
# 282 out of 3000 iterations
# 284 out of 3000 iterations
# 286 out of 3000 iterations
# 288 out of 3000 iterations
# 290 out of 3000 iterations
# 292 out of 3000 iterations
# 294 out of 3000 iterations
# 296 out of 3000 iterations
# 298 out of 3000 iterations
# 300 out of 3000 iterations
# 302 out of 3000 iterations
# 304 out of 3000 iterations
# 306 out of 3000 iterations
# 308 out of 3000 iterations
# 310 out of 3000 iterations
# 312 out of 3000 iterations
# 314 out of 3000 iterations
# 316 out of 3000 iterations
# 318 out of 3000 iterations
# 320 out of 3000 iterations
# 322 out of 3000 iterations
# 324 out of 3000 iterations
# 326 out of 3000 iterations
# 328 out of 3000 iterations
# 330 out of 3000 iterations
# 332 out of 3000 iterations
# 334 out of 3000 iterations
# 336 out of 3000 iterations
# 338 out of 3000 iterations
# 340 out of 3000 iterations
# 342 out of 3000 iterations
# 344 out of 3000 iterations
# 346 out of 3000 iterations
# 348 out of 3000 iterations
# 350 out of 3000 iterations
# 352 out of 3000 iterations
# 354 out of 3000 iterations
# 356 out of 3000 iterations
# 358 out of 3000 iterations
# 360 out of 3000 iterations
# 362 out of 3000 iterations
# 364 out of 3000 iterations
# 366 out of 3000 iterations
# 368 out of 3000 iterations
# 370 out of 3000 iterations
# 372 out of 3000 iterations
# 374 out of 3000 iterations
# 376 out of 3000 iterations
# 378 out of 3000 iterations
# 380 out of 3000 iterations
# 382 out of 3000 iterations
# 384 out of 3000 iterations
# 386 out of 3000 iterations
# 388 out of 3000 iterations
# 390 out of 3000 iterations
# 392 out of 3000 iterations
# 394 out of 3000 iterations
# 396 out of 3000 iterations
# 398 out of 3000 iterations
# 400 out of 3000 iterations
# 402 out of 3000 iterations
# 404 out of 3000 iterations
# 406 out of 3000 iterations
# 408 out of 3000 iterations
# 410 out of 3000 iterations
# 412 out of 3000 iterations
# 414 out of 3000 iterations
# 416 out of 3000 iterations
# 418 out of 3000 iterations
# 420 out of 3000 iterations
# 422 out of 3000 iterations
# 424 out of 3000 iterations
# 426 out of 3000 iterations
# 428 out of 3000 iterations
# 430 out of 3000 iterations
# 432 out of 3000 iterations
# 434 out of 3000 iterations
# 436 out of 3000 iterations
# 438 out of 3000 iterations
# 440 out of 3000 iterations
# 442 out of 3000 iterations
# 444 out of 3000 iterations
# 446 out of 3000 iterations
# 448 out of 3000 iterations
# 450 out of 3000 iterations
# 452 out of 3000 iterations
# 454 out of 3000 iterations
# 456 out of 3000 iterations
# 458 out of 3000 iterations
# 460 out of 3000 iterations
# 462 out of 3000 iterations
# 464 out of 3000 iterations
# 466 out of 3000 iterations
# 468 out of 3000 iterations
# 470 out of 3000 iterations
# 472 out of 3000 iterations
# 474 out of 3000 iterations
# 476 out of 3000 iterations
# 478 out of 3000 iterations
# 480 out of 3000 iterations
# 482 out of 3000 iterations
# 484 out of 3000 iterations
# 486 out of 3000 iterations
# 488 out of 3000 iterations
# 490 out of 3000 iterations
# 492 out of 3000 iterations
# 494 out of 3000 iterations
# 496 out of 3000 iterations
# 498 out of 3000 iterations
# 500 out of 3000 iterations
# 502 out of 3000 iterations
# 504 out of 3000 iterations
# 506 out of 3000 iterations
# 508 out of 3000 iterations
# 510 out of 3000 iterations
# 512 out of 3000 iterations
# 514 out of 3000 iterations
# 516 out of 3000 iterations
# 518 out of 3000 iterations
# 520 out of 3000 iterations
# 522 out of 3000 iterations
# 524 out of 3000 iterations
# 526 out of 3000 iterations
# 528 out of 3000 iterations
# 530 out of 3000 iterations
# 532 out of 3000 iterations
# 534 out of 3000 iterations
# 536 out of 3000 iterations
# 538 out of 3000 iterations
# 540 out of 3000 iterations
# 542 out of 3000 iterations
# 544 out of 3000 iterations
# 546 out of 3000 iterations
# 548 out of 3000 iterations
# 550 out of 3000 iterations
# 552 out of 3000 iterations
# 554 out of 3000 iterations
# 556 out of 3000 iterations
# 558 out of 3000 iterations
# 560 out of 3000 iterations
# 562 out of 3000 iterations
# 564 out of 3000 iterations
# 566 out of 3000 iterations
# 568 out of 3000 iterations
# 570 out of 3000 iterations
# 572 out of 3000 iterations
# 574 out of 3000 iterations
# 576 out of 3000 iterations
# 578 out of 3000 iterations
# 580 out of 3000 iterations
# 582 out of 3000 iterations
# 584 out of 3000 iterations
# 586 out of 3000 iterations
# 588 out of 3000 iterations
# 590 out of 3000 iterations
# 592 out of 3000 iterations
# 594 out of 3000 iterations
# 596 out of 3000 iterations
# 598 out of 3000 iterations
# 600 out of 3000 iterations
# 602 out of 3000 iterations
# 604 out of 3000 iterations
# 606 out of 3000 iterations
# 608 out of 3000 iterations
# 610 out of 3000 iterations
# 612 out of 3000 iterations
# 614 out of 3000 iterations
# 616 out of 3000 iterations
# 618 out of 3000 iterations
# 620 out of 3000 iterations
# 622 out of 3000 iterations
# 624 out of 3000 iterations
# 626 out of 3000 iterations
# 628 out of 3000 iterations
# 630 out of 3000 iterations
# 632 out of 3000 iterations
# 634 out of 3000 iterations
# 636 out of 3000 iterations
# 638 out of 3000 iterations
# 640 out of 3000 iterations
# 642 out of 3000 iterations
# 644 out of 3000 iterations
# 646 out of 3000 iterations
# 648 out of 3000 iterations
# 650 out of 3000 iterations
# 652 out of 3000 iterations
# 654 out of 3000 iterations
# 656 out of 3000 iterations
# 658 out of 3000 iterations
# 660 out of 3000 iterations
# 662 out of 3000 iterations
# 664 out of 3000 iterations
# 666 out of 3000 iterations
# 668 out of 3000 iterations
# 670 out of 3000 iterations
# 672 out of 3000 iterations
# 674 out of 3000 iterations
# 676 out of 3000 iterations
# 678 out of 3000 iterations
# 680 out of 3000 iterations
# 682 out of 3000 iterations
# 684 out of 3000 iterations
# 686 out of 3000 iterations
# 688 out of 3000 iterations
# 690 out of 3000 iterations
# 692 out of 3000 iterations
# 694 out of 3000 iterations
# 696 out of 3000 iterations
# 698 out of 3000 iterations
# 700 out of 3000 iterations
# 702 out of 3000 iterations
# 704 out of 3000 iterations
# 706 out of 3000 iterations
# 708 out of 3000 iterations
# 710 out of 3000 iterations
# 712 out of 3000 iterations
# 714 out of 3000 iterations
# 716 out of 3000 iterations
# 718 out of 3000 iterations
# 720 out of 3000 iterations
# 722 out of 3000 iterations
# 724 out of 3000 iterations
# 726 out of 3000 iterations
# 728 out of 3000 iterations
# 730 out of 3000 iterations
# 732 out of 3000 iterations
# 734 out of 3000 iterations
# 736 out of 3000 iterations
# 738 out of 3000 iterations
# 740 out of 3000 iterations
# 742 out of 3000 iterations
# 744 out of 3000 iterations
# 746 out of 3000 iterations
# 748 out of 3000 iterations
# 750 out of 3000 iterations
# 752 out of 3000 iterations
# 754 out of 3000 iterations
# 756 out of 3000 iterations
# 758 out of 3000 iterations
# 760 out of 3000 iterations
# 762 out of 3000 iterations
# 764 out of 3000 iterations
# 766 out of 3000 iterations
# 768 out of 3000 iterations
# 770 out of 3000 iterations
# 772 out of 3000 iterations
# 774 out of 3000 iterations
# 776 out of 3000 iterations
# 778 out of 3000 iterations
# 780 out of 3000 iterations
# 782 out of 3000 iterations
# 784 out of 3000 iterations
# 786 out of 3000 iterations
# 788 out of 3000 iterations
# 790 out of 3000 iterations
# 792 out of 3000 iterations
# 794 out of 3000 iterations
# 796 out of 3000 iterations
# 798 out of 3000 iterations
# 800 out of 3000 iterations
# 802 out of 3000 iterations
# 804 out of 3000 iterations
# 806 out of 3000 iterations
# 808 out of 3000 iterations
# 810 out of 3000 iterations
# 812 out of 3000 iterations
# 814 out of 3000 iterations
# 816 out of 3000 iterations
# 818 out of 3000 iterations
# 820 out of 3000 iterations
# 822 out of 3000 iterations
# 824 out of 3000 iterations
# 826 out of 3000 iterations
# 828 out of 3000 iterations
# 830 out of 3000 iterations
# 832 out of 3000 iterations
# 834 out of 3000 iterations
# 836 out of 3000 iterations
# 838 out of 3000 iterations
# 840 out of 3000 iterations
# 842 out of 3000 iterations
# 844 out of 3000 iterations
# 846 out of 3000 iterations
# 848 out of 3000 iterations
# 850 out of 3000 iterations
# 852 out of 3000 iterations
# 854 out of 3000 iterations
# 856 out of 3000 iterations
# 858 out of 3000 iterations
# 860 out of 3000 iterations
# 862 out of 3000 iterations
# 864 out of 3000 iterations
# 866 out of 3000 iterations
# 868 out of 3000 iterations
# 870 out of 3000 iterations
# 872 out of 3000 iterations
# 874 out of 3000 iterations
# 876 out of 3000 iterations
# 878 out of 3000 iterations
# 880 out of 3000 iterations
# 882 out of 3000 iterations
# 884 out of 3000 iterations
# 886 out of 3000 iterations
# 888 out of 3000 iterations
# 890 out of 3000 iterations
# 892 out of 3000 iterations
# 894 out of 3000 iterations
# 896 out of 3000 iterations
# 898 out of 3000 iterations
# 900 out of 3000 iterations
# 902 out of 3000 iterations
# 904 out of 3000 iterations
# 906 out of 3000 iterations
# 908 out of 3000 iterations
# 910 out of 3000 iterations
# 912 out of 3000 iterations
# 914 out of 3000 iterations
# 916 out of 3000 iterations
# 918 out of 3000 iterations
# 920 out of 3000 iterations
# 922 out of 3000 iterations
# 924 out of 3000 iterations
# 926 out of 3000 iterations
# 928 out of 3000 iterations
# 930 out of 3000 iterations
# 932 out of 3000 iterations
# 934 out of 3000 iterations
# 936 out of 3000 iterations
# 938 out of 3000 iterations
# 940 out of 3000 iterations
# 942 out of 3000 iterations
# 944 out of 3000 iterations
# 946 out of 3000 iterations
# 948 out of 3000 iterations
# 950 out of 3000 iterations
# 952 out of 3000 iterations
# 954 out of 3000 iterations
# 956 out of 3000 iterations
# 958 out of 3000 iterations
# 960 out of 3000 iterations
# 962 out of 3000 iterations
# 964 out of 3000 iterations
# 966 out of 3000 iterations
# 968 out of 3000 iterations
# 970 out of 3000 iterations
# 972 out of 3000 iterations
# 974 out of 3000 iterations
# 976 out of 3000 iterations
# 978 out of 3000 iterations
# 980 out of 3000 iterations
# 982 out of 3000 iterations
# 984 out of 3000 iterations
# 986 out of 3000 iterations
# 988 out of 3000 iterations
# 990 out of 3000 iterations
# 992 out of 3000 iterations
# 994 out of 3000 iterations
# 996 out of 3000 iterations
# 998 out of 3000 iterations
# 1000 out of 3000 iterations
# 1002 out of 3000 iterations
# 1004 out of 3000 iterations
# 1006 out of 3000 iterations
# 1008 out of 3000 iterations
# 1010 out of 3000 iterations
# 1012 out of 3000 iterations
# 1014 out of 3000 iterations
# 1016 out of 3000 iterations
# 1018 out of 3000 iterations
# 1020 out of 3000 iterations
# 1022 out of 3000 iterations
# 1024 out of 3000 iterations
# 1026 out of 3000 iterations
# 1028 out of 3000 iterations
# 1030 out of 3000 iterations
# 1032 out of 3000 iterations
# 1034 out of 3000 iterations
# 1036 out of 3000 iterations
# 1038 out of 3000 iterations
# 1040 out of 3000 iterations
# 1042 out of 3000 iterations
# 1044 out of 3000 iterations
# 1046 out of 3000 iterations
# 1048 out of 3000 iterations
# 1050 out of 3000 iterations
# 1052 out of 3000 iterations
# 1054 out of 3000 iterations
# 1056 out of 3000 iterations
# 1058 out of 3000 iterations
# 1060 out of 3000 iterations
# 1062 out of 3000 iterations
# 1064 out of 3000 iterations
# 1066 out of 3000 iterations
# 1068 out of 3000 iterations
# 1070 out of 3000 iterations
# 1072 out of 3000 iterations
# 1074 out of 3000 iterations
# 1076 out of 3000 iterations
# 1078 out of 3000 iterations
# 1080 out of 3000 iterations
# 1082 out of 3000 iterations
# 1084 out of 3000 iterations
# 1086 out of 3000 iterations
# 1088 out of 3000 iterations
# 1090 out of 3000 iterations
# 1092 out of 3000 iterations
# 1094 out of 3000 iterations
# 1096 out of 3000 iterations
# 1098 out of 3000 iterations
# 1100 out of 3000 iterations
# 1102 out of 3000 iterations
# 1104 out of 3000 iterations
# 1106 out of 3000 iterations
# 1108 out of 3000 iterations
# 1110 out of 3000 iterations
# 1112 out of 3000 iterations
# 1114 out of 3000 iterations
# 1116 out of 3000 iterations
# 1118 out of 3000 iterations
# 1120 out of 3000 iterations
# 1122 out of 3000 iterations
# 1124 out of 3000 iterations
# 1126 out of 3000 iterations
# 1128 out of 3000 iterations
# 1130 out of 3000 iterations
# 1132 out of 3000 iterations
# 1134 out of 3000 iterations
# 1136 out of 3000 iterations
# 1138 out of 3000 iterations
# 1140 out of 3000 iterations
# 1142 out of 3000 iterations
# 1144 out of 3000 iterations
# 1146 out of 3000 iterations
# 1148 out of 3000 iterations
# 1150 out of 3000 iterations
# 1152 out of 3000 iterations
# 1154 out of 3000 iterations
# 1156 out of 3000 iterations
# 1158 out of 3000 iterations
# 1160 out of 3000 iterations
# 1162 out of 3000 iterations
# 1164 out of 3000 iterations
# 1166 out of 3000 iterations
# 1168 out of 3000 iterations
# 1170 out of 3000 iterations
# 1172 out of 3000 iterations
# 1174 out of 3000 iterations
# 1176 out of 3000 iterations
# 1178 out of 3000 iterations
# 1180 out of 3000 iterations
# 1182 out of 3000 iterations
# 1184 out of 3000 iterations
# 1186 out of 3000 iterations
# 1188 out of 3000 iterations
# 1190 out of 3000 iterations
# 1192 out of 3000 iterations
# 1194 out of 3000 iterations
# 1196 out of 3000 iterations
# 1198 out of 3000 iterations
# 1200 out of 3000 iterations
# 1202 out of 3000 iterations
# 1204 out of 3000 iterations
# 1206 out of 3000 iterations
# 1208 out of 3000 iterations
# 1210 out of 3000 iterations
# 1212 out of 3000 iterations
# 1214 out of 3000 iterations
# 1216 out of 3000 iterations
# 1218 out of 3000 iterations
# 1220 out of 3000 iterations
# 1222 out of 3000 iterations
# 1224 out of 3000 iterations
# 1226 out of 3000 iterations
# 1228 out of 3000 iterations
# 1230 out of 3000 iterations
# 1232 out of 3000 iterations
# 1234 out of 3000 iterations
# 1236 out of 3000 iterations
# 1238 out of 3000 iterations
# 1240 out of 3000 iterations
# 1242 out of 3000 iterations
# 1244 out of 3000 iterations
# 1246 out of 3000 iterations
# 1248 out of 3000 iterations
# 1250 out of 3000 iterations
# 1252 out of 3000 iterations
# 1254 out of 3000 iterations
# 1256 out of 3000 iterations
# 1258 out of 3000 iterations
# 1260 out of 3000 iterations
# 1262 out of 3000 iterations
# 1264 out of 3000 iterations
# 1266 out of 3000 iterations
# 1268 out of 3000 iterations
# 1270 out of 3000 iterations
# 1272 out of 3000 iterations
# 1274 out of 3000 iterations
# 1276 out of 3000 iterations
# 1278 out of 3000 iterations
# 1280 out of 3000 iterations
# 1282 out of 3000 iterations
# 1284 out of 3000 iterations
# 1286 out of 3000 iterations
# 1288 out of 3000 iterations
# 1290 out of 3000 iterations
# 1292 out of 3000 iterations
# 1294 out of 3000 iterations
# 1296 out of 3000 iterations
# 1298 out of 3000 iterations
# 1300 out of 3000 iterations
# 1302 out of 3000 iterations
# 1304 out of 3000 iterations
# 1306 out of 3000 iterations
# 1308 out of 3000 iterations
# 1310 out of 3000 iterations
# 1312 out of 3000 iterations
# 1314 out of 3000 iterations
# 1316 out of 3000 iterations
# 1318 out of 3000 iterations
# 1320 out of 3000 iterations
# 1322 out of 3000 iterations
# 1324 out of 3000 iterations
# 1326 out of 3000 iterations
# 1328 out of 3000 iterations
# 1330 out of 3000 iterations
# 1332 out of 3000 iterations
# 1334 out of 3000 iterations
# 1336 out of 3000 iterations
# 1338 out of 3000 iterations
# 1340 out of 3000 iterations
# 1342 out of 3000 iterations
# 1344 out of 3000 iterations
# 1346 out of 3000 iterations
# 1348 out of 3000 iterations
# 1350 out of 3000 iterations
# 1352 out of 3000 iterations
# 1354 out of 3000 iterations
# 1356 out of 3000 iterations
# 1358 out of 3000 iterations
# 1360 out of 3000 iterations
# 1362 out of 3000 iterations
# 1364 out of 3000 iterations
# 1366 out of 3000 iterations
# 1368 out of 3000 iterations
# 1370 out of 3000 iterations
# 1372 out of 3000 iterations
# 1374 out of 3000 iterations
# 1376 out of 3000 iterations
# 1378 out of 3000 iterations
# 1380 out of 3000 iterations
# 1382 out of 3000 iterations
# 1384 out of 3000 iterations
# 1386 out of 3000 iterations
# 1388 out of 3000 iterations
# 1390 out of 3000 iterations
# 1392 out of 3000 iterations
# 1394 out of 3000 iterations
# 1396 out of 3000 iterations
# 1398 out of 3000 iterations
# 1400 out of 3000 iterations
# 1402 out of 3000 iterations
# 1404 out of 3000 iterations
# 1406 out of 3000 iterations
# 1408 out of 3000 iterations
# 1410 out of 3000 iterations
# 1412 out of 3000 iterations
# 1414 out of 3000 iterations
# 1416 out of 3000 iterations
# 1418 out of 3000 iterations
# 1420 out of 3000 iterations
# 1422 out of 3000 iterations
# 1424 out of 3000 iterations
# 1426 out of 3000 iterations
# 1428 out of 3000 iterations
# 1430 out of 3000 iterations
# 1432 out of 3000 iterations
# 1434 out of 3000 iterations
# 1436 out of 3000 iterations
# 1438 out of 3000 iterations
# 1440 out of 3000 iterations
# 1442 out of 3000 iterations
# 1444 out of 3000 iterations
# 1446 out of 3000 iterations
# 1448 out of 3000 iterations
# 1450 out of 3000 iterations
# 1452 out of 3000 iterations
# 1454 out of 3000 iterations
# 1456 out of 3000 iterations
# 1458 out of 3000 iterations
# 1460 out of 3000 iterations
# 1462 out of 3000 iterations
# 1464 out of 3000 iterations
# 1466 out of 3000 iterations
# 1468 out of 3000 iterations
# 1470 out of 3000 iterations
# 1472 out of 3000 iterations
# 1474 out of 3000 iterations
# 1476 out of 3000 iterations
# 1478 out of 3000 iterations
# 1480 out of 3000 iterations
# 1482 out of 3000 iterations
# 1484 out of 3000 iterations
# 1486 out of 3000 iterations
# 1488 out of 3000 iterations
# 1490 out of 3000 iterations
# 1492 out of 3000 iterations
# 1494 out of 3000 iterations
# 1496 out of 3000 iterations
# 1498 out of 3000 iterations
# 1500 out of 3000 iterations
# 1502 out of 3000 iterations
# 1504 out of 3000 iterations
# 1506 out of 3000 iterations
# 1508 out of 3000 iterations
# 1510 out of 3000 iterations
# 1512 out of 3000 iterations
# 1514 out of 3000 iterations
# 1516 out of 3000 iterations
# 1518 out of 3000 iterations
# 1520 out of 3000 iterations
# 1522 out of 3000 iterations
# 1524 out of 3000 iterations
# 1526 out of 3000 iterations
# 1528 out of 3000 iterations
# 1530 out of 3000 iterations
# 1532 out of 3000 iterations
# 1534 out of 3000 iterations
# 1536 out of 3000 iterations
# 1538 out of 3000 iterations
# 1540 out of 3000 iterations
# 1542 out of 3000 iterations
# 1544 out of 3000 iterations
# 1546 out of 3000 iterations
# 1548 out of 3000 iterations
# 1550 out of 3000 iterations
# 1552 out of 3000 iterations
# 1554 out of 3000 iterations
# 1556 out of 3000 iterations
# 1558 out of 3000 iterations
# 1560 out of 3000 iterations
# 1562 out of 3000 iterations
# 1564 out of 3000 iterations
# 1566 out of 3000 iterations
# 1568 out of 3000 iterations
# 1570 out of 3000 iterations
# 1572 out of 3000 iterations
# 1574 out of 3000 iterations
# 1576 out of 3000 iterations
# 1578 out of 3000 iterations
# 1580 out of 3000 iterations
# 1582 out of 3000 iterations
# 1584 out of 3000 iterations
# 1586 out of 3000 iterations
# 1588 out of 3000 iterations
# 1590 out of 3000 iterations
# 1592 out of 3000 iterations
# 1594 out of 3000 iterations
# 1596 out of 3000 iterations
# 1598 out of 3000 iterations
# 1600 out of 3000 iterations
# 1602 out of 3000 iterations
# 1604 out of 3000 iterations
# 1606 out of 3000 iterations
# 1608 out of 3000 iterations
# 1610 out of 3000 iterations
# 1612 out of 3000 iterations
# 1614 out of 3000 iterations
# 1616 out of 3000 iterations
# 1618 out of 3000 iterations
# 1620 out of 3000 iterations
# 1622 out of 3000 iterations
# 1624 out of 3000 iterations
# 1626 out of 3000 iterations
# 1628 out of 3000 iterations
# 1630 out of 3000 iterations
# 1632 out of 3000 iterations
# 1634 out of 3000 iterations
# 1636 out of 3000 iterations
# 1638 out of 3000 iterations
# 1640 out of 3000 iterations
# 1642 out of 3000 iterations
# 1644 out of 3000 iterations
# 1646 out of 3000 iterations
# 1648 out of 3000 iterations
# 1650 out of 3000 iterations
# 1652 out of 3000 iterations
# 1654 out of 3000 iterations
# 1656 out of 3000 iterations
# 1658 out of 3000 iterations
# 1660 out of 3000 iterations
# 1662 out of 3000 iterations
# 1664 out of 3000 iterations
# 1666 out of 3000 iterations
# 1668 out of 3000 iterations
# 1670 out of 3000 iterations
# 1672 out of 3000 iterations
# 1674 out of 3000 iterations
# 1676 out of 3000 iterations
# 1678 out of 3000 iterations
# 1680 out of 3000 iterations
# 1682 out of 3000 iterations
# 1684 out of 3000 iterations
# 1686 out of 3000 iterations
# 1688 out of 3000 iterations
# 1690 out of 3000 iterations
# 1692 out of 3000 iterations
# 1694 out of 3000 iterations
# 1696 out of 3000 iterations
# 1698 out of 3000 iterations
# 1700 out of 3000 iterations
# 1702 out of 3000 iterations
# 1704 out of 3000 iterations
# 1706 out of 3000 iterations
# 1708 out of 3000 iterations
# 1710 out of 3000 iterations
# 1712 out of 3000 iterations
# 1714 out of 3000 iterations
# 1716 out of 3000 iterations
# 1718 out of 3000 iterations
# 1720 out of 3000 iterations
# 1722 out of 3000 iterations
# 1724 out of 3000 iterations
# 1726 out of 3000 iterations
# 1728 out of 3000 iterations
# 1730 out of 3000 iterations
# 1732 out of 3000 iterations
# 1734 out of 3000 iterations
# 1736 out of 3000 iterations
# 1738 out of 3000 iterations
# 1740 out of 3000 iterations
# 1742 out of 3000 iterations
# 1744 out of 3000 iterations
# 1746 out of 3000 iterations
# 1748 out of 3000 iterations
# 1750 out of 3000 iterations
# 1752 out of 3000 iterations
# 1754 out of 3000 iterations
# 1756 out of 3000 iterations
# 1758 out of 3000 iterations
# 1760 out of 3000 iterations
# 1762 out of 3000 iterations
# 1764 out of 3000 iterations
# 1766 out of 3000 iterations
# 1768 out of 3000 iterations
# 1770 out of 3000 iterations
# 1772 out of 3000 iterations
# 1774 out of 3000 iterations
# 1776 out of 3000 iterations
# 1778 out of 3000 iterations
# 1780 out of 3000 iterations
# 1782 out of 3000 iterations
# 1784 out of 3000 iterations
# 1786 out of 3000 iterations
# 1788 out of 3000 iterations
# 1790 out of 3000 iterations
# 1792 out of 3000 iterations
# 1794 out of 3000 iterations
# 1796 out of 3000 iterations
# 1798 out of 3000 iterations
# 1800 out of 3000 iterations
# 1802 out of 3000 iterations
# 1804 out of 3000 iterations
# 1806 out of 3000 iterations
# 1808 out of 3000 iterations
# 1810 out of 3000 iterations
# 1812 out of 3000 iterations
# 1814 out of 3000 iterations
# 1816 out of 3000 iterations
# 1818 out of 3000 iterations
# 1820 out of 3000 iterations
# 1822 out of 3000 iterations
# 1824 out of 3000 iterations
# 1826 out of 3000 iterations
# 1828 out of 3000 iterations
# 1830 out of 3000 iterations
# 1832 out of 3000 iterations
# 1834 out of 3000 iterations
# 1836 out of 3000 iterations
# 1838 out of 3000 iterations
# 1840 out of 3000 iterations
# 1842 out of 3000 iterations
# 1844 out of 3000 iterations
# 1846 out of 3000 iterations
# 1848 out of 3000 iterations
# 1850 out of 3000 iterations
# 1852 out of 3000 iterations
# 1854 out of 3000 iterations
# 1856 out of 3000 iterations
# 1858 out of 3000 iterations
# 1860 out of 3000 iterations
# 1862 out of 3000 iterations
# 1864 out of 3000 iterations
# 1866 out of 3000 iterations
# 1868 out of 3000 iterations
# 1870 out of 3000 iterations
# 1872 out of 3000 iterations
# 1874 out of 3000 iterations
# 1876 out of 3000 iterations
# 1878 out of 3000 iterations
# 1880 out of 3000 iterations
# 1882 out of 3000 iterations
# 1884 out of 3000 iterations
# 1886 out of 3000 iterations
# 1888 out of 3000 iterations
# 1890 out of 3000 iterations
# 1892 out of 3000 iterations
# 1894 out of 3000 iterations
# 1896 out of 3000 iterations
# 1898 out of 3000 iterations
# 1900 out of 3000 iterations
# 1902 out of 3000 iterations
# 1904 out of 3000 iterations
# 1906 out of 3000 iterations
# 1908 out of 3000 iterations
# 1910 out of 3000 iterations
# 1912 out of 3000 iterations
# 1914 out of 3000 iterations
# 1916 out of 3000 iterations
# 1918 out of 3000 iterations
# 1920 out of 3000 iterations
# 1922 out of 3000 iterations
# 1924 out of 3000 iterations
# 1926 out of 3000 iterations
# 1928 out of 3000 iterations
# 1930 out of 3000 iterations
# 1932 out of 3000 iterations
# 1934 out of 3000 iterations
# 1936 out of 3000 iterations
# 1938 out of 3000 iterations
# 1940 out of 3000 iterations
# 1942 out of 3000 iterations
# 1944 out of 3000 iterations
# 1946 out of 3000 iterations
# 1948 out of 3000 iterations
# 1950 out of 3000 iterations
# 1952 out of 3000 iterations
# 1954 out of 3000 iterations
# 1956 out of 3000 iterations
# 1958 out of 3000 iterations
# 1960 out of 3000 iterations
# 1962 out of 3000 iterations
# 1964 out of 3000 iterations
# 1966 out of 3000 iterations
# 1968 out of 3000 iterations
# 1970 out of 3000 iterations
# 1972 out of 3000 iterations
# 1974 out of 3000 iterations
# 1976 out of 3000 iterations
# 1978 out of 3000 iterations
# 1980 out of 3000 iterations
# 1982 out of 3000 iterations
# 1984 out of 3000 iterations
# 1986 out of 3000 iterations
# 1988 out of 3000 iterations
# 1990 out of 3000 iterations
# 1992 out of 3000 iterations
# 1994 out of 3000 iterations
# 1996 out of 3000 iterations
# 1998 out of 3000 iterations
# 2000 out of 3000 iterations
# 2002 out of 3000 iterations
# 2004 out of 3000 iterations
# 2006 out of 3000 iterations
# 2008 out of 3000 iterations
# 2010 out of 3000 iterations
# 2012 out of 3000 iterations
# 2014 out of 3000 iterations
# 2016 out of 3000 iterations
# 2018 out of 3000 iterations
# 2020 out of 3000 iterations
# 2022 out of 3000 iterations
# 2024 out of 3000 iterations
# 2026 out of 3000 iterations
# 2028 out of 3000 iterations
# 2030 out of 3000 iterations
# 2032 out of 3000 iterations
# 2034 out of 3000 iterations
# 2036 out of 3000 iterations
# 2038 out of 3000 iterations
# 2040 out of 3000 iterations
# 2042 out of 3000 iterations
# 2044 out of 3000 iterations
# 2046 out of 3000 iterations
# 2048 out of 3000 iterations
# 2050 out of 3000 iterations
# 2052 out of 3000 iterations
# 2054 out of 3000 iterations
# 2056 out of 3000 iterations
# 2058 out of 3000 iterations
# 2060 out of 3000 iterations
# 2062 out of 3000 iterations
# 2064 out of 3000 iterations
# 2066 out of 3000 iterations
# 2068 out of 3000 iterations
# 2070 out of 3000 iterations
# 2072 out of 3000 iterations
# 2074 out of 3000 iterations
# 2076 out of 3000 iterations
# 2078 out of 3000 iterations
# 2080 out of 3000 iterations
# 2082 out of 3000 iterations
# 2084 out of 3000 iterations
# 2086 out of 3000 iterations
# 2088 out of 3000 iterations
# 2090 out of 3000 iterations
# 2092 out of 3000 iterations
# 2094 out of 3000 iterations
# 2096 out of 3000 iterations
# 2098 out of 3000 iterations
# 2100 out of 3000 iterations
# 2102 out of 3000 iterations
# 2104 out of 3000 iterations
# 2106 out of 3000 iterations
# 2108 out of 3000 iterations
# 2110 out of 3000 iterations
# 2112 out of 3000 iterations
# 2114 out of 3000 iterations
# 2116 out of 3000 iterations
# 2118 out of 3000 iterations
# 2120 out of 3000 iterations
# 2122 out of 3000 iterations
# 2124 out of 3000 iterations
# 2126 out of 3000 iterations
# 2128 out of 3000 iterations
# 2130 out of 3000 iterations
# 2132 out of 3000 iterations
# 2134 out of 3000 iterations
# 2136 out of 3000 iterations
# 2138 out of 3000 iterations
# 2140 out of 3000 iterations
# 2142 out of 3000 iterations
# 2144 out of 3000 iterations
# 2146 out of 3000 iterations
# 2148 out of 3000 iterations
# 2150 out of 3000 iterations
# 2152 out of 3000 iterations
# 2154 out of 3000 iterations
# 2156 out of 3000 iterations
# 2158 out of 3000 iterations
# 2160 out of 3000 iterations
# 2162 out of 3000 iterations
# 2164 out of 3000 iterations
# 2166 out of 3000 iterations
# 2168 out of 3000 iterations
# 2170 out of 3000 iterations
# 2172 out of 3000 iterations
# 2174 out of 3000 iterations
# 2176 out of 3000 iterations
# 2178 out of 3000 iterations
# 2180 out of 3000 iterations
# 2182 out of 3000 iterations
# 2184 out of 3000 iterations
# 2186 out of 3000 iterations
# 2188 out of 3000 iterations
# 2190 out of 3000 iterations
# 2192 out of 3000 iterations
# 2194 out of 3000 iterations
# 2196 out of 3000 iterations
# 2198 out of 3000 iterations
# 2200 out of 3000 iterations
# 2202 out of 3000 iterations
# 2204 out of 3000 iterations
# 2206 out of 3000 iterations
# 2208 out of 3000 iterations
# 2210 out of 3000 iterations
# 2212 out of 3000 iterations
# 2214 out of 3000 iterations
# 2216 out of 3000 iterations
# 2218 out of 3000 iterations
# 2220 out of 3000 iterations
# 2222 out of 3000 iterations
# 2224 out of 3000 iterations
# 2226 out of 3000 iterations
# 2228 out of 3000 iterations
# 2230 out of 3000 iterations
# 2232 out of 3000 iterations
# 2234 out of 3000 iterations
# 2236 out of 3000 iterations
# 2238 out of 3000 iterations
# 2240 out of 3000 iterations
# 2242 out of 3000 iterations
# 2244 out of 3000 iterations
# 2246 out of 3000 iterations
# 2248 out of 3000 iterations
# 2250 out of 3000 iterations
# 2252 out of 3000 iterations
# 2254 out of 3000 iterations
# 2256 out of 3000 iterations
# 2258 out of 3000 iterations
# 2260 out of 3000 iterations
# 2262 out of 3000 iterations
# 2264 out of 3000 iterations
# 2266 out of 3000 iterations
# 2268 out of 3000 iterations
# 2270 out of 3000 iterations
# 2272 out of 3000 iterations
# 2274 out of 3000 iterations
# 2276 out of 3000 iterations
# 2278 out of 3000 iterations
# 2280 out of 3000 iterations
# 2282 out of 3000 iterations
# 2284 out of 3000 iterations
# 2286 out of 3000 iterations
# 2288 out of 3000 iterations
# 2290 out of 3000 iterations
# 2292 out of 3000 iterations
# 2294 out of 3000 iterations
# 2296 out of 3000 iterations
# 2298 out of 3000 iterations
# 2300 out of 3000 iterations
# 2302 out of 3000 iterations
# 2304 out of 3000 iterations
# 2306 out of 3000 iterations
# 2308 out of 3000 iterations
# 2310 out of 3000 iterations
# 2312 out of 3000 iterations
# 2314 out of 3000 iterations
# 2316 out of 3000 iterations
# 2318 out of 3000 iterations
# 2320 out of 3000 iterations
# 2322 out of 3000 iterations
# 2324 out of 3000 iterations
# 2326 out of 3000 iterations
# 2328 out of 3000 iterations
# 2330 out of 3000 iterations
# 2332 out of 3000 iterations
# 2334 out of 3000 iterations
# 2336 out of 3000 iterations
# 2338 out of 3000 iterations
# 2340 out of 3000 iterations
# 2342 out of 3000 iterations
# 2344 out of 3000 iterations
# 2346 out of 3000 iterations
# 2348 out of 3000 iterations
# 2350 out of 3000 iterations
# 2352 out of 3000 iterations
# 2354 out of 3000 iterations
# 2356 out of 3000 iterations
# 2358 out of 3000 iterations
# 2360 out of 3000 iterations
# 2362 out of 3000 iterations
# 2364 out of 3000 iterations
# 2366 out of 3000 iterations
# 2368 out of 3000 iterations
# 2370 out of 3000 iterations
# 2372 out of 3000 iterations
# 2374 out of 3000 iterations
# 2376 out of 3000 iterations
# 2378 out of 3000 iterations
# 2380 out of 3000 iterations
# 2382 out of 3000 iterations
# 2384 out of 3000 iterations
# 2386 out of 3000 iterations
# 2388 out of 3000 iterations
# 2390 out of 3000 iterations
# 2392 out of 3000 iterations
# 2394 out of 3000 iterations
# 2396 out of 3000 iterations
# 2398 out of 3000 iterations
# 2400 out of 3000 iterations
# 2402 out of 3000 iterations
# 2404 out of 3000 iterations
# 2406 out of 3000 iterations
# 2408 out of 3000 iterations
# 2410 out of 3000 iterations
# 2412 out of 3000 iterations
# 2414 out of 3000 iterations
# 2416 out of 3000 iterations
# 2418 out of 3000 iterations
# 2420 out of 3000 iterations
# 2422 out of 3000 iterations
# 2424 out of 3000 iterations
# 2426 out of 3000 iterations
# 2428 out of 3000 iterations
# 2430 out of 3000 iterations
# 2432 out of 3000 iterations
# 2434 out of 3000 iterations
# 2436 out of 3000 iterations
# 2438 out of 3000 iterations
# 2440 out of 3000 iterations
# 2442 out of 3000 iterations
# 2444 out of 3000 iterations
# 2446 out of 3000 iterations
# 2448 out of 3000 iterations
# 2450 out of 3000 iterations
# 2452 out of 3000 iterations
# 2454 out of 3000 iterations
# 2456 out of 3000 iterations
# 2458 out of 3000 iterations
# 2460 out of 3000 iterations
# 2462 out of 3000 iterations
# 2464 out of 3000 iterations
# 2466 out of 3000 iterations
# 2468 out of 3000 iterations
# 2470 out of 3000 iterations
# 2472 out of 3000 iterations
# 2474 out of 3000 iterations
# 2476 out of 3000 iterations
# 2478 out of 3000 iterations
# 2480 out of 3000 iterations
# 2482 out of 3000 iterations
# 2484 out of 3000 iterations
# 2486 out of 3000 iterations
# 2488 out of 3000 iterations
# 2490 out of 3000 iterations
# 2492 out of 3000 iterations
# 2494 out of 3000 iterations
# 2496 out of 3000 iterations
# 2498 out of 3000 iterations
# 2500 out of 3000 iterations
# 2502 out of 3000 iterations
# 2504 out of 3000 iterations
# 2506 out of 3000 iterations
# 2508 out of 3000 iterations
# 2510 out of 3000 iterations
# 2512 out of 3000 iterations
# 2514 out of 3000 iterations
# 2516 out of 3000 iterations
# 2518 out of 3000 iterations
# 2520 out of 3000 iterations
# 2522 out of 3000 iterations
# 2524 out of 3000 iterations
# 2526 out of 3000 iterations
# 2528 out of 3000 iterations
# 2530 out of 3000 iterations
# 2532 out of 3000 iterations
# 2534 out of 3000 iterations
# 2536 out of 3000 iterations
# 2538 out of 3000 iterations
# 2540 out of 3000 iterations
# 2542 out of 3000 iterations
# 2544 out of 3000 iterations
# 2546 out of 3000 iterations
# 2548 out of 3000 iterations
# 2550 out of 3000 iterations
# 2552 out of 3000 iterations
# 2554 out of 3000 iterations
# 2556 out of 3000 iterations
# 2558 out of 3000 iterations
# 2560 out of 3000 iterations
# 2562 out of 3000 iterations
# 2564 out of 3000 iterations
# 2566 out of 3000 iterations
# 2568 out of 3000 iterations
# 2570 out of 3000 iterations
# 2572 out of 3000 iterations
# 2574 out of 3000 iterations
# 2576 out of 3000 iterations
# 2578 out of 3000 iterations
# 2580 out of 3000 iterations
# 2582 out of 3000 iterations
# 2584 out of 3000 iterations
# 2586 out of 3000 iterations
# 2588 out of 3000 iterations
# 2590 out of 3000 iterations
# 2592 out of 3000 iterations
# 2594 out of 3000 iterations
# 2596 out of 3000 iterations
# 2598 out of 3000 iterations
# 2600 out of 3000 iterations
# 2602 out of 3000 iterations
# 2604 out of 3000 iterations
# 2606 out of 3000 iterations
# 2608 out of 3000 iterations
# 2610 out of 3000 iterations
# 2612 out of 3000 iterations
# 2614 out of 3000 iterations
# 2616 out of 3000 iterations
# 2618 out of 3000 iterations
# 2620 out of 3000 iterations
# 2622 out of 3000 iterations
# 2624 out of 3000 iterations
# 2626 out of 3000 iterations
# 2628 out of 3000 iterations
# 2630 out of 3000 iterations
# 2632 out of 3000 iterations
# 2634 out of 3000 iterations
# 2636 out of 3000 iterations
# 2638 out of 3000 iterations
# 2640 out of 3000 iterations
# 2642 out of 3000 iterations
# 2644 out of 3000 iterations
# 2646 out of 3000 iterations
# 2648 out of 3000 iterations
# 2650 out of 3000 iterations
# 2652 out of 3000 iterations
# 2654 out of 3000 iterations
# 2656 out of 3000 iterations
# 2658 out of 3000 iterations
# 2660 out of 3000 iterations
# 2662 out of 3000 iterations
# 2664 out of 3000 iterations
# 2666 out of 3000 iterations
# 2668 out of 3000 iterations
# 2670 out of 3000 iterations
# 2672 out of 3000 iterations
# 2674 out of 3000 iterations
# 2676 out of 3000 iterations
# 2678 out of 3000 iterations
# 2680 out of 3000 iterations
# 2682 out of 3000 iterations
# 2684 out of 3000 iterations
# 2686 out of 3000 iterations
# 2688 out of 3000 iterations
# 2690 out of 3000 iterations
# 2692 out of 3000 iterations
# 2694 out of 3000 iterations
# 2696 out of 3000 iterations
# 2698 out of 3000 iterations
# 2700 out of 3000 iterations
# 2702 out of 3000 iterations
# 2704 out of 3000 iterations
# 2706 out of 3000 iterations
# 2708 out of 3000 iterations
# 2710 out of 3000 iterations
# 2712 out of 3000 iterations
# 2714 out of 3000 iterations
# 2716 out of 3000 iterations
# 2718 out of 3000 iterations
# 2720 out of 3000 iterations
# 2722 out of 3000 iterations
# 2724 out of 3000 iterations
# 2726 out of 3000 iterations
# 2728 out of 3000 iterations
# 2730 out of 3000 iterations
# 2732 out of 3000 iterations
# 2734 out of 3000 iterations
# 2736 out of 3000 iterations
# 2738 out of 3000 iterations
# 2740 out of 3000 iterations
# 2742 out of 3000 iterations
# 2744 out of 3000 iterations
# 2746 out of 3000 iterations
# 2748 out of 3000 iterations
# 2750 out of 3000 iterations
# 2752 out of 3000 iterations
# 2754 out of 3000 iterations
# 2756 out of 3000 iterations
# 2758 out of 3000 iterations
# 2760 out of 3000 iterations
# 2762 out of 3000 iterations
# 2764 out of 3000 iterations
# 2766 out of 3000 iterations
# 2768 out of 3000 iterations
# 2770 out of 3000 iterations
# 2772 out of 3000 iterations
# 2774 out of 3000 iterations
# 2776 out of 3000 iterations
# 2778 out of 3000 iterations
# 2780 out of 3000 iterations
# 2782 out of 3000 iterations
# 2784 out of 3000 iterations
# 2786 out of 3000 iterations
# 2788 out of 3000 iterations
# 2790 out of 3000 iterations
# 2792 out of 3000 iterations
# 2794 out of 3000 iterations
# 2796 out of 3000 iterations
# 2798 out of 3000 iterations
# 2800 out of 3000 iterations
# 2802 out of 3000 iterations
# 2804 out of 3000 iterations
# 2806 out of 3000 iterations
# 2808 out of 3000 iterations
# 2810 out of 3000 iterations
# 2812 out of 3000 iterations
# 2814 out of 3000 iterations
# 2816 out of 3000 iterations
# 2818 out of 3000 iterations
# 2820 out of 3000 iterations
# 2822 out of 3000 iterations
# 2824 out of 3000 iterations
# 2826 out of 3000 iterations
# 2828 out of 3000 iterations
# 2830 out of 3000 iterations
# 2832 out of 3000 iterations
# 2834 out of 3000 iterations
# 2836 out of 3000 iterations
# 2838 out of 3000 iterations
# 2840 out of 3000 iterations
# 2842 out of 3000 iterations
# 2844 out of 3000 iterations
# 2846 out of 3000 iterations
# 2848 out of 3000 iterations
# 2850 out of 3000 iterations
# 2852 out of 3000 iterations
# 2854 out of 3000 iterations
# 2856 out of 3000 iterations
# 2858 out of 3000 iterations
# 2860 out of 3000 iterations
# 2862 out of 3000 iterations
# 2864 out of 3000 iterations
# 2866 out of 3000 iterations
# 2868 out of 3000 iterations
# 2870 out of 3000 iterations
# 2872 out of 3000 iterations
# 2874 out of 3000 iterations
# 2876 out of 3000 iterations
# 2878 out of 3000 iterations
# 2880 out of 3000 iterations
# 2882 out of 3000 iterations
# 2884 out of 3000 iterations
# 2886 out of 3000 iterations
# 2888 out of 3000 iterations
# 2890 out of 3000 iterations
# 2892 out of 3000 iterations
# 2894 out of 3000 iterations
# 2896 out of 3000 iterations
# 2898 out of 3000 iterations
# 2900 out of 3000 iterations
# 2902 out of 3000 iterations
# 2904 out of 3000 iterations
# 2906 out of 3000 iterations
# 2908 out of 3000 iterations
# 2910 out of 3000 iterations
# 2912 out of 3000 iterations
# 2914 out of 3000 iterations
# 2916 out of 3000 iterations
# 2918 out of 3000 iterations
# 2920 out of 3000 iterations
# 2922 out of 3000 iterations
# 2924 out of 3000 iterations
# 2926 out of 3000 iterations
# 2928 out of 3000 iterations
# 2930 out of 3000 iterations
# 2932 out of 3000 iterations
# 2934 out of 3000 iterations
# 2936 out of 3000 iterations
# 2938 out of 3000 iterations
# 2940 out of 3000 iterations
# 2942 out of 3000 iterations
# 2944 out of 3000 iterations
# 2946 out of 3000 iterations
# 2948 out of 3000 iterations
# 2950 out of 3000 iterations
# 2952 out of 3000 iterations
# 2954 out of 3000 iterations
# 2956 out of 3000 iterations
# 2958 out of 3000 iterations
# 2960 out of 3000 iterations
# 2962 out of 3000 iterations
# 2964 out of 3000 iterations
# 2966 out of 3000 iterations
# 2968 out of 3000 iterations
# 2970 out of 3000 iterations
# 2972 out of 3000 iterations
# 2974 out of 3000 iterations
# 2976 out of 3000 iterations
# 2978 out of 3000 iterations
# 2980 out of 3000 iterations
# 2982 out of 3000 iterations
# 2984 out of 3000 iterations
# 2986 out of 3000 iterations
# 2988 out of 3000 iterations
# 2990 out of 3000 iterations
# 2992 out of 3000 iterations
# 2994 out of 3000 iterations
# 2996 out of 3000 iterations
# 2998 out of 3000 iterations
# ...finish
# (array([[-0.01777887,  0.00860446, -0.00405833, ...,  0.02387394,
#           0.01914402,  0.02355444],
#         [ 0.02545108, -0.01428862, -0.00600298, ..., -0.02158426,
#          -0.0099351 , -0.01190659]]), array([[ 0.90785264, -0.41928939],
#         [ 0.01343123,  0.9999098 ]]), array([[ 0.68857834,  0.72516197],
#         [-0.72516197,  0.68857834]]))

# %%
sparse_data = my_spca.transform(X)

plt.figure(figsize=(15,5)); 

plt.subplot(121); 
plt.scatter(X[y==0, 0], X[y==0, 1], color='red',  alpha=0.5)
plt.scatter(X[y==1, 0], X[y==1, 1], color='blue', alpha=0.5)
pca11=plt.arrow   (0, 0, *vec[:,0] * val[0], head_width=0.05, head_length=0.05,color='Green',  label='First PC')
pca12=plt.arrow   (0, 0, *vec[:,1] * val[1], head_width=0.05, head_length=0.05,color='magenta',label='Second PC')
plt.grid(True); 

new_pc_cen = sparse_data - sparse_data.mean(0,keepdims=True)
cov        = new_pc_cen.T @ new_pc_cen /(new_pc_cen.shape[0] - 1)
val,vec    = np.linalg.eigh(cov)

plt.subplot(122); 
plt.scatter(new_pc[y==0, 0], new_pc[y==0, 1], color='red',  alpha=0.5)
plt.scatter(new_pc[y==1, 0], new_pc[y==1, 1], color='blue', alpha=0.5)
pca21=plt.arrow   (0, 0, *vec[:,0] * val[0], head_width=0.005, head_length=0.005,color='Green',  label='First PC')
pca22=plt.arrow   (0, 0, *vec[:,1] * val[1], head_width=0.005, head_length=0.005,color='magenta',label='Second PC')
plt.grid(True); 

plt.show()

# %%
# robust pca
from __future__ import division, print_function

import numpy as np

try:
    from pylab import plt
except ImportError:
    print('Unable to import pylab. R_pca.plot_fit() will not work.')

try:
    # Python 2: 'xrange' is the iterative version
    range = xrange
except NameError:
    # Python 3: 'range' is iterative - no need for 'xrange'
    pass


class R_pca:

    def __init__(self, D, mu=None, lmbda=None):
        self.D = D
        self.S = np.zeros(self.D.shape)
        self.Y = np.zeros(self.D.shape)

        if mu:
            self.mu = mu
        else:
            self.mu = np.prod(self.D.shape) / (4 * self.norm_p(self.D, 2))

        self.mu_inv = 1 / self.mu

        if lmbda:
            self.lmbda = lmbda
        else:
            self.lmbda = 1 / np.sqrt(np.max(self.D.shape))

    @staticmethod
    def norm_p(M, p):
        return np.sum(np.power(M, p))

    @staticmethod
    def shrink(M, tau):
        return np.sign(M) * np.maximum((np.abs(M) - tau), np.zeros(M.shape))

    def svd_threshold(self, M, tau):
        U, S, V = np.linalg.svd(M, full_matrices=False)
        return np.dot(U, np.dot(np.diag(self.shrink(S, tau)), V))

    def fit(self, tol=None, max_iter=1000, iter_print=100):
        iter = 0
        err = np.Inf
        Sk = self.S
        Yk = self.Y
        Lk = np.zeros(self.D.shape)

        if tol:
            _tol = tol
        else:
            _tol = 1E-7 * self.norm_p(np.abs(self.D), 2)

        while (err > _tol) and iter < max_iter:
            Lk = self.svd_threshold(
                self.D - Sk + self.mu_inv * Yk, self.mu_inv)
            Sk = self.shrink(
                self.D - Lk + (self.mu_inv * Yk), self.mu_inv * self.lmbda)
            Yk = Yk + self.mu * (self.D - Lk - Sk)
            err = self.norm_p(np.abs(self.D - Lk - Sk), 2)
            iter += 1
            if (iter % iter_print) == 0 or iter == 1 or iter > max_iter or err <= _tol:
                print('iteration: {0}, error: {1}'.format(iter, err))

        self.L = Lk
        self.S = Sk
        return Lk, Sk

    def plot_fit(self, size=None, tol=0.1, axis_on=True):

        n, d = self.D.shape

        if size:
            nrows, ncols = size
        else:
            sq = np.ceil(np.sqrt(n))
            nrows = int(sq)
            ncols = int(sq)

        ymin = np.nanmin(self.D)
        ymax = np.nanmax(self.D)
        print('ymin: {0}, ymax: {1}'.format(ymin, ymax))

        numplots = np.min([n, nrows * ncols])
        plt.figure()

        for n in range(numplots):
            plt.subplot(nrows, ncols, n + 1)
            plt.ylim((ymin - tol, ymax + tol))
            plt.plot(self.L[n, :] + self.S[n, :], 'r')
            plt.plot(self.L[n, :], 'b')
            if not axis_on:
                plt.axis('off')

# %%
rpca = R_pca(X)
L, S = rpca.fit(max_iter=10000, iter_print=1)
print(L.shape)
print(S.shape)
# Out:
# iteration: 1, error: 0.06131479292765401
# iteration: 2, error: 1.7526867056850554e-06
# (4000, 2)
# (4000, 2)

# %%
plt.figure(figsize=(15,5)); 

plt.subplot(131); 
plt.scatter(X[y==0, 0], X[y==0, 1], color='red',  alpha=0.5)
plt.scatter(X[y==1, 0], X[y==1, 1], color='blue', alpha=0.5)
pca11=plt.arrow   (0, 0, *vec[:,0] * val[0], head_width=0.05, head_length=0.05,color='Green',  label='First PC')
pca12=plt.arrow   (0, 0, *vec[:,1] * val[1], head_width=0.05, head_length=0.05,color='magenta',label='Second PC')
plt.grid(True); 

plt.subplot(132); 
plt.scatter(L[y==0, 0], L[y==0, 1], color='red',  alpha=0.5)
plt.scatter(L[y==1, 0], L[y==1, 1], color='blue', alpha=0.5)
# pca21=plt.arrow   (0, 0, *project_V[:,0] * val_reduced[0], head_width=0.05, head_length=0.05,color='Green',  label='First PC')
# pca22=plt.arrow   (0, 0, *project_V[:,1] * val_reduced[1], head_width=0.05, head_length=0.05,color='magenta',label='Second PC')
plt.grid(True); 

plt.subplot(133); 
plt.scatter(S[y==0, 0], S[y==0, 1], color='red',  alpha=0.5)
plt.scatter(S[y==1, 0], S[y==1, 1], color='blue', alpha=0.5)
# pca21=plt.arrow   (0, 0, *revertedV[:,0] * val_reduced[0], head_width=0.05, head_length=0.05,color='Green',  label='First PC')
# pca22=plt.arrow   (0, 0, *revertedV[:,1] * val_reduced[1], head_width=0.05, head_length=0.05,color='magenta',label='Second PC')
plt.grid(True); 

plt.show()

# %% [markdown]
# # Reference
# 1. tf.set_random_seed | TensorFlow. (2018). TensorFlow. Retrieved 28 October 2018, from https://www.tensorflow.org/api_docs/python/tf/set_random_seed
# 2. Comparing different hierarchical linkage methods on toy datasets — scikit-learn 0.20.0 documentation. (2018). Scikit-learn.org. Retrieved 28 October 2018, from http://scikit-learn.org/stable/auto_examples/cluster/plot_linkage_comparison.html#sphx-glr-auto-examples-cluster-plot-linkage-comparison-py
# 3. VanderPlas, J. (2018). Multiple Subplots | Python Data Science Handbook. Jakevdp.github.io. Retrieved 28 October 2018, from https://jakevdp.github.io/PythonDataScienceHandbook/04.08-multiple-subplots.html
# 4. object, M. (2018). Matplotlib returning a plot object. Stack Overflow. Retrieved 28 October 2018, from https://stackoverflow.com/questions/43925337/matplotlib-returning-a-plot-object
# 5. Plot randomly generated classification dataset — scikit-learn 0.20.0 documentation. (2018). Scikit-learn.org. Retrieved 28 October 2018, from http://scikit-learn.org/stable/auto_examples/datasets/plot_random_dataset.html#sphx-glr-auto-examples-datasets-plot-random-dataset-py
# 6. 5. Dataset loading utilities — scikit-learn 0.20.0 documentation. (2018). Scikit-learn.org. Retrieved 28 October 2018, from http://scikit-learn.org/stable/datasets/index.html
# 7. mplot3d tutorial — Matplotlib 2.0.2 documentation. (2018). Matplotlib.org. Retrieved 28 October 2018, from https://matplotlib.org/mpl_toolkits/mplot3d/tutorial.html
# 8. matplotlib, H. (2018). How to plot vectors in python using matplotlib. Stack Overflow. Retrieved 28 October 2018, from https://stackoverflow.com/questions/42281966/how-to-plot-vectors-in-python-using-matplotlib
# 9. arrow, M. (2018). Matplotlib legend for an arrow. Stack Overflow. Retrieved 28 October 2018, from https://stackoverflow.com/questions/22348229/matplotlib-legend-for-an-arrow
# 10. plt colors - Google Search. (2018). Google.ca. Retrieved 28 October 2018, from https://www.google.ca/search?q=plt+colors&rlz=1C1CHBF_enCA771CA771&oq=plt+colors&aqs=chrome..69i57j0l5.1038j0j7&sourceid=chrome&ie=UTF-8
# 11. Brownlee, J. (2018). A Gentle Introduction to Singular-Value Decomposition for Machine Learning. Machine Learning Mastery. Retrieved 28 October 2018, from https://machinelearningmastery.com/singular-value-decomposition-for-machine-learning/
# 12. https://www.quora.com/Why-do-we-need-to-center-the-data-for-Principle-Components-Analysis
# 13. Distance Matrix Vectorization Trick – Manifold Blog – Medium. (2016). Medium. Retrieved 29 October 2018, from https://medium.com/dataholiks-distillery/l2-distance-matrix-vectorization-trick-26aa3247ac6c
# 14. (pdist), H. (2018). How does condensed distance matrix work? (pdist). Stack Overflow. Retrieved 29 October 2018, from https://stackoverflow.com/questions/13079563/how-does-condensed-distance-matrix-work-pdist
# 15. aboyker/easyspc. (2018). GitHub. Retrieved 29 October 2018, from https://github.com/aboyker/easyspc/blob/master/build/lib/easyspc/__init__.py
# 16.
