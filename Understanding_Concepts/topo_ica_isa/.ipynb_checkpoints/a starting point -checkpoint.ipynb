# %%
import tensorflow as tf 
import numpy as np
import sklearn 
import matplotlib.pyplot as plt

# %%
# 0. import random data and play around
np.random.seed(0)
data = np.random.normal(size=(1000,1))
plt.figure(figsize=(15,7))
plt.subplot(121)
plt.scatter(range(len(data)),data[:,0])
plt.subplot(122)
plt.hist(data)
plt.show()

# %%
# centering
def center(X):
    """
     shift the row-wise mean to 0
    """
    centered = X - np.mean(X, axis=1).reshape(len(X), 1)
    return centered

# %%
! git add . 
! git commit -m 'from mac'
! git push
# Out:
# [master 515ab828] from mac
#  2 files changed, 51 insertions(+)
#  create mode 100644 Understanding_Concepts/topo_ica_isa/.ipynb_checkpoints/a starting point -checkpoint.ipynb
#  create mode 100644 Understanding_Concepts/topo_ica_isa/a starting point .ipynb
# Counting objects: 6, done.
# Delta compression using up to 4 threads.
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 1003 bytes | 1003.00 KiB/s, done.
# Total 6 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/JaeDukSeo/Daily-Neural-Network-Practice-2
#    dd0bb7ef..515ab828  master -> master
