# %%
# import library 
import pickle
import tensorflow as tf
import numpy as np
import sys, os,cv2
from scipy.misc import imread,imresize
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from imgaug import augmenters as iaa
import imgaug as ia
from scipy.ndimage import zoom
from sklearn.utils import shuffle
import matplotlib.animation as animation
import seaborn as sns

plt.style.use('seaborn-white')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
np.random.seed(6278);tf.set_random_seed(6728);ia.seed(6278)

# %%
# try the KPCA on a smaller dimension dataset
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=2000, random_state=123,noise =0.1)
plt.figure(figsize=(8,6))
plt.scatter(X[y==0, 0], X[y==0, 1], color='red',  alpha=0.5)
plt.scatter(X[y==1, 0], X[y==1, 1], color='blue', alpha=0.5)
plt.title('A nonlinear 2Ddataset'); plt.ylabel('y coordinate'); plt.xlabel('x coordinate')
plt.show()

# %%
# define the kernel pca layer
# Class for TF
class KPCA_layer():
    
    def __init__(self):
        pass

    def feedforward(self,input,n_components,gamma = 15):
        self.input = input
        self.distance_matrix = -2 * tf.matmul(input,tf.transpose(input)) + tf.reduce_sum(input**2,axis=1) + tf.reduce_sum(input**2,axis=1)[:,tf.newaxis]
        self.k = tf.exp(-gamma * self.distance_matrix)
        
        N = self.k.shape[0].value
        ones = tf.ones([N,N],dtype=tf.float64) / N
        self.center_k = self.k - tf.matmul(ones,self.k) - tf.matmul(self.k,ones) + tf.matmul(tf.matmul(ones,self.k),ones)
        
        self.eigval,self.eigvec = tf.linalg.eigh(self.center_k)
        self.small_eigvec = self.eigvec[:,-n_components:]
        
        return self.small_eigvec
    
    def backprop_upsuper(self):
        pass
    
    def backprop(self,grad):
        pass

# %% [markdown]
# # Reference
# 1. sklearn.datasets.make_moons — scikit-learn 0.20.0 documentation. (2018). Scikit-learn.org. Retrieved 26 October 2018, from http://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html
# 2.

# %%
! git all-go
# Out:
# [master f5297388] s
#  2 files changed, 300 insertions(+), 300 deletions(-)
#  rewrite Understanding_Concepts/kernel_pca/.ipynb_checkpoints/a starting-checkpoint.ipynb (85%)
#  rewrite Understanding_Concepts/kernel_pca/a starting.ipynb (85%)
# warning: LF will be replaced by CRLF in Understanding_Concepts/kernel_pca/.ipynb_checkpoints/a starting-checkpoint.ipynb.
# The file will have its original line endings in your working directory.
# warning: LF will be replaced by CRLF in Understanding_Concepts/kernel_pca/a starting.ipynb.
# The file will have its original line endings in your working directory.
# To https://github.com/JaeDukSeo/Daily-Neural-Network-Practice-2
#    66f50392..f5297388  master -> master
