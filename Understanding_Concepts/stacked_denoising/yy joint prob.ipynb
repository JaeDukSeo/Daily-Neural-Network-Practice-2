# %%
import numpy   as np
import seaborn as sns; sns.set(style="white", color_codes=True)
import matplotlib.pyplot as plt

# %%
one = np.random.randn(1000)
sns.jointplot(x=one,y=one, kind="kde", space=0, color="g")
