# %%
# import library
import numpy as np 
import tensorflow as tf

np.random.seed(6789)
tf.set_random_seed(678)

import matplotlib.pyplot as plt 
plt.style.use('seaborn')
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)
matplotlib.rcParams['figure.figsize'] = (30.0, 10.0)
import pandas as pd
from sklearn.datasets import make_moons

# %%
# create data
data,label = make_moons(1000,noise=0.2,random_state=20)
plt.scatter(data[:,0],data[:,1],c=label,cmap='Wistia_r')
plt.show()

# %% [markdown]
# # Reference
# 1. url, P. (2018). Pandas read_csv from url. Stack Overflow. Retrieved 25 November 2018, from https://stackoverflow.com/questions/32400867/pandas-read-csv-from-url/41880513#41880513
# 2. python, C. (2018). Convert a list of data from url to csv in python. Stack Overflow. Retrieved 25 November 2018, from https://stackoverflow.com/questions/46410307/convert-a-list-of-data-from-url-to-csv-in-python
# 3. notebook?, H. (2018). How to set the matplotlib figure default size in ipython notebook?. Stack Overflow. Retrieved 25 November 2018, from https://stackoverflow.com/questions/17230797/how-to-set-the-matplotlib-figure-default-size-in-ipython-notebook
# 4. Matplotlib?, H. (2018). How do I set the figure title and axes labels font size in Matplotlib?. Stack Overflow. Retrieved 25 November 2018, from https://stackoverflow.com/questions/12444716/how-do-i-set-the-figure-title-and-axes-labels-font-size-in-matplotlib
