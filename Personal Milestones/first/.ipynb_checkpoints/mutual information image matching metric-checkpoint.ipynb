# %%
# import lib
import numpy as np 
import matplotlib.pyplot as plt 
plt.rcParams['image.cmap'] = 'gray'
plt.rcParams['image.interpolation'] = 'nearest'
from PIL import Image
import requests
from io import BytesIO

# %%
url = "http://affordablescan.com/blog/wp-content/uploads/2018/04/brainMRI.png"
img_1 = np.array(Image.open(BytesIO(requests.get(url).content))).mean(2)
url = "http://affordablescan.com/blog/wp-content/uploads/2018/04/brainMRI.png"
img_2 = np.array(Image.open(BytesIO(requests.get(url).content))).mean(2)

plt.imshow(img_1)
plt.show()
# Out:
# (781, 733)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-03b23f08b4ff> in <module>
#       5 plt.imshow(img_1)
#       6 plt.show()
# ----> 7 plt.imshow(img_1[:,:,1])
#       8 plt.show()
#       9
#
# IndexError: too many indices for array
