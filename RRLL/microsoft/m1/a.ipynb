# %%
import numpy as np
import sys

if "../" not in sys.path:
    sys.path.append("../") 

from lib.envs.simple_rooms import SimpleRoomsEnv
from lib.envs.cliff_walking import CliffWalkingEnv
from lib.simulation import Experiment
import matplotlib.pyplot as plt

interactive = True
# %matplotlib nbagg    

class Agent(object):

    def __init__(self, actions):
        self.actions = actions
        self.num_actions = len(actions)

    def act(self, obs):
        raise NotImplementedError
        
class RandomAgent(Agent):
    
    def __init__(self, actions):
        super(RandomAgent, self).__init__(actions)
    
    def act(self, obs):
        return np.random.randint(0,self.num_actions)
    
    
class PerfectAgent(Agent):
    
    def __init__(self, actions):
        super(PerfectAgent, self).__init__(actions)
        self.perfect_table = np.array(
            [
                1,1,1,3,
                1,0,1,3,
                1,3,3,3,
                1,1,1,1
            ]
        )
    
    def act(self, obs):
        where_i_am = np.argmax(obs)
        if where_i_am == 0 : return np.random.randint(0,self.num_actions)
        which_action = self.perfect_table[where_i_am]
        return which_action

# %%
max_number_of_episodes = 100
env = SimpleRoomsEnv()
agent = PerfectAgent(range(env.action_space.n))
experiment = Experiment(env, agent)
experiment.run_agent(max_number_of_episodes, interactive)
# Out:
# <div id='fc70cf46-3531-4cc8-84c1-baef9d56997e'></div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-f982a3a9ec95> in <module>()
#       3 agent = PerfectAgent(range(env.action_space.n))
#       4 experiment = Experiment(env, agent)
# ----> 5 experiment.run_agent(max_number_of_episodes, interactive)
#
# ~\Desktop\Daily-Neural-Network-Practice-2\RRLL\microsoft\lib\simulation.py in run_agent(self, max_number_of_episodes, interactive, display_frequency)
#     129
#     130                 # choose action from state
# --> 131                 action = self.agent.act(state)
#     132
#     133                 # take action, observe reward and next state
#
# <ipython-input-74-ecbd4d93d39f> in act(self, obs)
#      46     def act(self, obs):
#      47         where_i_am = np.argmax(obs)
# ---> 48         if where_i_am == 0 : return np.radnom.randint(0,self.num_actions)
#      49         which_action = self.perfect_table[where_i_am]
#      50         return which_action
#
# AttributeError: module 'numpy' has no attribute 'radnom'

# %%
max_number_of_episodes = 10
env = CliffWalkingEnv()
agent = RandomAgent(range(env.action_space.n))
experiment = Experiment(env, agent)
experiment.run_agent(max_number_of_episodes, interactive)
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
interactive = False
# %matplotlib inline

# %%
max_number_of_episodes = 100
env = SimpleRoomsEnv()
agent = RandomAgent(range(env.action_space.n))
experiment = Experiment(env, agent)
experiment.run_agent(max_number_of_episodes, interactive)

# %%
max_number_of_episodes = 100
env = CliffWalkingEnv()
agent = RandomAgent(range(env.action_space.n))
experiment = Experiment(env, agent)
experiment.run_agent(max_number_of_episodes, interactive)
