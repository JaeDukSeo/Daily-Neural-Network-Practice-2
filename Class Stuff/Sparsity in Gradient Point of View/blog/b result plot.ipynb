# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
plt.style.use('seaborn')

# %%
# read all of results
def read_npy(folder):

    Z_gradp1 = np.asarray(np.load(folder+'/gradp1.npy')); Z_gradp2 = np.asarray(np.load(folder+'/gradp2.npy')); Z_gradp3 = np.asarray(np.load(folder+'/gradp3.npy'))
    Z_gradp4 = np.asarray(np.load(folder+'/gradp4.npy')); Z_gradp5 = np.asarray(np.load(folder+'/gradp5.npy')); Z_gradp6 = np.asarray(np.load(folder+'/gradp6.npy'))

    Z_gradw1 = np.asarray(np.load(folder+'/gradw1.npy')); Z_gradw2 = np.asarray(np.load(folder+'/gradw2.npy')); Z_gradw3 = np.asarray(np.load(folder+'/gradw3.npy')); 
    Z_gradw4 = np.asarray(np.load(folder+'/gradw4.npy')); Z_gradw5 = np.asarray(np.load(folder+'/gradw5.npy')); Z_gradw6 = np.asarray(np.load(folder+'/gradw6.npy')); 

    Z_layer1 = np.asarray(np.load(folder+'/llayer1.npy')); Z_layer2 = np.asarray(np.load(folder+'/llayer2.npy'));  Z_layer3 = np.asarray(np.load(folder+'/llayer3.npy')); 
    Z_layer4 = np.asarray(np.load(folder+'/llayer4.npy')); Z_layer5 = np.asarray(np.load(folder+'/llayer5.npy'));  Z_layer6 = np.asarray(np.load(folder+'/llayer6.npy')); 

    Z_layera1 = np.asarray(np.load(folder+'/llayer1a.npy')); Z_layera2 = np.asarray(np.load(folder+'/llayer2a.npy')); Z_layera3 = np.asarray(np.load(folder+'/llayer3a.npy')); 
    Z_layera4 = np.asarray(np.load(folder+'/llayer4a.npy')); Z_layera5 = np.asarray(np.load(folder+'/llayer5a.npy')); Z_layera6 = np.asarray(np.load(folder+'/llayer6a.npy')); 

    Z_moment1   = np.asarray(np.load(folder+'/gradup1.npy')); Z_moment2   = np.asarray(np.load(folder+'/gradup2.npy'));  Z_moment3   = np.asarray(np.load(folder+'/gradup3.npy')); 
    Z_moment4   = np.asarray(np.load(folder+'/gradup4.npy')); Z_moment5   = np.asarray(np.load(folder+'/gradup5.npy'));  Z_moment6   = np.asarray(np.load(folder+'/gradup6.npy')); 

    Z_weights1  = np.asarray(np.load(folder+'/weight1.npy'));  Z_weights2  = np.asarray(np.load(folder+'/weight2.npy')); Z_weights3  = np.asarray(np.load(folder+'/weight3.npy')); 
    Z_weights4  = np.asarray(np.load(folder+'/weight4.npy'));  Z_weights5  = np.asarray(np.load(folder+'/weight5.npy')); Z_weights6  = np.asarray(np.load(folder+'/weight6.npy')); 

    gradp = np.array([Z_gradp1,Z_gradp2,Z_gradp3,Z_gradp4,Z_gradp5,Z_gradp6])
    gradw = np.array([Z_gradw1,Z_gradw2,Z_gradw3,Z_gradw4,Z_gradw5,Z_gradw6])
    layer = np.array([Z_layer1,Z_layer2,Z_layer3,Z_layer4,Z_layer5,Z_layer6])
    layera= np.array([Z_layera1,Z_layera2,Z_layera3,Z_layera4,Z_layera5,Z_layera6])
    moment= np.array([Z_moment1,Z_moment2,Z_moment3,Z_moment4,Z_moment5,Z_moment6])
    weight= np.array([Z_weights1,Z_weights2,Z_weights3,Z_weights4,Z_weights5,Z_weights6])
    
    return gradp,gradw,layer,layera,moment,weight,np.asarray(np.load(folder+'/train_acc.npy')),np.asarray(np.load(folder+'/test_acc.npy'))

Z_gradp,Z_gradw,Z_layer,Z_layera,Z_moment,Z_weight,Z_train_acc,Z_test_acc = read_npy('Z')
A_gradp,A_gradw,A_layer,A_layera,A_moment,A_weight,A_train_acc,A_test_acc = read_npy('A')
B_gradp,B_gradw,B_layer,B_layera,B_moment,B_weight,B_train_acc,B_test_acc = read_npy('B')
C_gradp,C_gradw,C_layer,C_layera,C_moment,C_weight,C_train_acc,C_test_acc = read_npy('C')
D_gradp,D_gradw,D_layer,D_layera,D_moment,D_weight,D_train_acc,D_test_acc = read_npy('D')
E_gradp,E_gradw,E_layer,E_layera,E_moment,E_weight,E_train_acc,E_test_acc = read_npy('E')
F_gradp,F_gradw,F_layer,F_layera,F_moment,F_weight,F_train_acc,F_test_acc = read_npy('F')
G_gradp,G_gradw,G_layer,G_layera,G_moment,G_weight,G_train_acc,G_test_acc = read_npy('G')
H_gradp,H_gradw,H_layer,H_layera,H_moment,H_weight,H_train_acc,H_test_acc = read_npy('H')
I_gradp,I_gradw,I_layer,I_layera,I_moment,I_weight,I_train_acc,I_test_acc = read_npy('I')
J_gradp,J_gradw,J_layer,J_layera,J_moment,J_weight,J_train_acc,J_test_acc = read_npy('J')

# %%
# train/test
plt.figure(figsize=(10,10))
plt.title('Training Accuracy')
plt.plot(Z_train_acc,label="Z",c='red')
plt.plot(A_train_acc,label="A",c='orange')
plt.plot(B_train_acc,label="B",c='yellow')
plt.plot(C_train_acc,label="C",c='green')
plt.plot(D_train_acc,label="D",c='blue')
plt.plot(E_train_acc,label="E",c='purple')
plt.plot(F_train_acc,label="F",c='black')
plt.plot(G_train_acc,label="G",c='white')
plt.plot(H_train_acc,label="H",c='pink')
plt.plot(I_train_acc,label="I",c='gold')
plt.plot(J_train_acc,label="J",c='silver')
plt.legend()
plt.show()

plt.figure(figsize=(10,10))
plt.title('Testing Accuracy')
plt.plot(Z_test_acc,label="Z",c='red')
plt.plot(A_test_acc,label="A",c='orange')
plt.plot(B_test_acc,label="B",c='yellow')
plt.plot(C_test_acc,label="C",c='green')
plt.plot(D_test_acc,label="D",c='blue')
plt.plot(E_test_acc,label="E",c='purple')
plt.plot(F_test_acc,label="F",c='black')
plt.plot(G_test_acc,label="G",c='white')
plt.plot(H_test_acc,label="H",c='pink')
plt.plot(I_test_acc,label="I",c='gold')
plt.plot(J_test_acc,label="J",c='silver')
plt.legend()
plt.show()

# %%
# funtion for ploting
def plot_everything(Z_gradp,
                    A_gradp,
                    B_gradp,
                    C_gradp,
                    D_gradp,
                    E_gradp,
                    F_gradp,
                    G_gradp,                    
                    H_gradp,
                    I_gradp,
                    J_gradp,
                    name,special):
    plt.figure(figsize=(20,15))
    G = gridspec.GridSpec(3, 2)
    
    if special:
        
    else:
    plt.subplot(G[0, 0]).set_title("Average Mean "+name,fontsize=20)
    plt.subplot(G[0, 0]).plot(Z_gradp.mean(0)[0,:],label="Z",c='red')
    plt.subplot(G[0, 0]).plot(A_gradp.mean(0)[0,:],label="A",c='orange')
    plt.subplot(G[0, 0]).plot(B_gradp.mean(0)[0,:],label="B",c='yellow')
    plt.subplot(G[0, 0]).plot(C_gradp.mean(0)[0,:],label="C",c='green')
    plt.subplot(G[0, 0]).plot(D_gradp.mean(0)[0,:],label="D",c='blue')
    plt.subplot(G[0, 0]).plot(E_gradp.mean(0)[0,:],label="E",c='purple')
    plt.subplot(G[0, 0]).plot(F_gradp.mean(0)[0,:],label="F",c='black')
    plt.subplot(G[0, 0]).plot(G_gradp.mean(0)[0,:],label="G",c='white')
    plt.subplot(G[0, 0]).plot(H_gradp.mean(0)[0,:],label="H",c='pink')
    plt.subplot(G[0, 0]).plot(I_gradp.mean(0)[0,:],label="I",c='gold')
    plt.subplot(G[0, 0]).plot(J_gradp.mean(0)[0,:],label="J",c='silver')
    plt.legend()

    plt.subplot(G[0, 1]).set_title("Average STD "+name,fontsize=20)
    plt.subplot(G[0, 1]).plot(Z_gradp.mean(0)[1,:],label="Z",c='red')
    plt.subplot(G[0, 1]).plot(A_gradp.mean(0)[1,:],label="A",c='orange')
    plt.subplot(G[0, 1]).plot(B_gradp.mean(0)[1,:],label="B",c='yellow')
    plt.subplot(G[0, 1]).plot(C_gradp.mean(0)[1,:],label="C",c='green')
    plt.subplot(G[0, 1]).plot(D_gradp.mean(0)[1,:],label="D",c='blue')
    plt.subplot(G[0, 1]).plot(E_gradp.mean(0)[1,:],label="E",c='purple')
    plt.subplot(G[0, 1]).plot(F_gradp.mean(0)[1,:],label="F",c='black')
    plt.subplot(G[0, 1]).plot(G_gradp.mean(0)[1,:],label="G",c='white')
    plt.subplot(G[0, 1]).plot(H_gradp.mean(0)[1,:],label="H",c='pink')
    plt.subplot(G[0, 1]).plot(I_gradp.mean(0)[1,:],label="I",c='gold')
    plt.subplot(G[0, 1]).plot(J_gradp.mean(0)[1,:],label="J",c='silver')
    plt.legend()

    plt.subplot(G[1, 0]).set_title("Average Skewness "+name,fontsize=20)
    plt.subplot(G[1, 0]).plot(Z_gradp.mean(0)[2,:],label="Z",c='red')
    plt.subplot(G[1, 0]).plot(A_gradp.mean(0)[2,:],label="A",c='orange')
    plt.subplot(G[1, 0]).plot(B_gradp.mean(0)[2,:],label="B",c='yellow')
    plt.subplot(G[1, 0]).plot(C_gradp.mean(0)[2,:],label="C",c='green')
    plt.subplot(G[1, 0]).plot(D_gradp.mean(0)[2,:],label="D",c='blue')
    plt.subplot(G[1, 0]).plot(E_gradp.mean(0)[2,:],label="E",c='purple')
    plt.subplot(G[1, 0]).plot(F_gradp.mean(0)[2,:],label="F",c='black')
    plt.subplot(G[1, 0]).plot(G_gradp.mean(0)[2,:],label="G",c='white')
    plt.subplot(G[1, 0]).plot(H_gradp.mean(0)[2,:],label="H",c='pink')
    plt.subplot(G[1, 0]).plot(I_gradp.mean(0)[2,:],label="I",c='gold')
    plt.subplot(G[1, 0]).plot(J_gradp.mean(0)[2,:],label="J",c='silver')
    plt.legend()

    plt.subplot(G[1, 1]).set_title("Average Kurtosis "+name,fontsize=20)
    plt.subplot(G[1, 1]).plot(Z_gradp.mean(0)[3,:],label="Z",c='red')
    plt.subplot(G[1, 1]).plot(A_gradp.mean(0)[3,:],label="A",c='orange')
    plt.subplot(G[1, 1]).plot(B_gradp.mean(0)[3,:],label="B",c='yellow')
    plt.subplot(G[1, 1]).plot(C_gradp.mean(0)[3,:],label="C",c='green')
    plt.subplot(G[1, 1]).plot(D_gradp.mean(0)[3,:],label="D",c='blue')
    plt.subplot(G[1, 1]).plot(E_gradp.mean(0)[3,:],label="E",c='purple')
    plt.subplot(G[1, 1]).plot(F_gradp.mean(0)[3,:],label="F",c='black')
    plt.subplot(G[1, 1]).plot(G_gradp.mean(0)[3,:],label="G",c='white')
    plt.subplot(G[1, 1]).plot(H_gradp.mean(0)[3,:],label="H",c='pink')
    plt.subplot(G[1, 1]).plot(I_gradp.mean(0)[3,:],label="I",c='gold')
    plt.subplot(G[1, 1]).plot(J_gradp.mean(0)[3,:],label="J",c='silver')
    plt.legend()

    plt.subplot(G[2, 0]).set_title("Average # of non-zero elements "+name,fontsize=20)
    plt.subplot(G[2, 0]).plot(Z_gradp.mean(0)[4,:],label="Z",c='red')
    plt.subplot(G[2, 0]).plot(A_gradp.mean(0)[4,:],label="A",c='orange')
    plt.subplot(G[2, 0]).plot(B_gradp.mean(0)[4,:],label="B",c='yellow')
    plt.subplot(G[2, 0]).plot(C_gradp.mean(0)[4,:],label="C",c='green')
    plt.subplot(G[2, 0]).plot(D_gradp.mean(0)[4,:],label="D",c='blue')
    plt.subplot(G[2, 0]).plot(E_gradp.mean(0)[4,:],label="E",c='purple')
    plt.subplot(G[2, 0]).plot(F_gradp.mean(0)[4,:],label="F",c='black')
    plt.subplot(G[2, 0]).plot(G_gradp.mean(0)[4,:],label="G",c='white')
    plt.subplot(G[2, 0]).plot(H_gradp.mean(0)[4,:],label="H",c='pink')
    plt.subplot(G[2, 0]).plot(I_gradp.mean(0)[4,:],label="I",c='gold')
    plt.subplot(G[2, 0]).plot(J_gradp.mean(0)[4,:],label="J",c='silver')
    plt.legend()


    plt.subplot(G[2, 1]).set_title("Train(solid line)/Test(dotted line) Accuracy",fontsize=20)
    plt.subplot(G[2, 1]).plot(Z_train_acc,'-', label="Z train",c='red')
    plt.subplot(G[2, 1]).plot(Z_test_acc, '--',label="Z test", c='red')
    plt.subplot(G[2, 1]).plot(A_train_acc,'-', label="A train",c='orange')
    plt.subplot(G[2, 1]).plot(A_test_acc, '--',label="A test", c='orange')
    plt.subplot(G[2, 1]).plot(B_train_acc,'-', label="B train",c='yellow')
    plt.subplot(G[2, 1]).plot(B_test_acc, '--',label="B test", c='yellow')
    plt.subplot(G[2, 1]).plot(C_train_acc,'-', label="C train",c='green')
    plt.subplot(G[2, 1]).plot(C_test_acc, '--',label="C test", c='green')
    plt.subplot(G[2, 1]).plot(D_train_acc,'-', label="D train",c='blue')
    plt.subplot(G[2, 1]).plot(D_test_acc, '--',label="D test", c='blue')
    plt.subplot(G[2, 1]).plot(E_train_acc,'-', label="E train",c='purple')
    plt.subplot(G[2, 1]).plot(E_test_acc, '--',label="E test", c='purple')
    plt.subplot(G[2, 1]).plot(F_train_acc,'-', label="F train",c='black')
    plt.subplot(G[2, 1]).plot(F_test_acc, '--',label="F test", c='black')
    plt.subplot(G[2, 1]).plot(G_train_acc,'-', label="G train",c='white')
    plt.subplot(G[2, 1]).plot(G_test_acc, '--',label="G test", c='white')
    plt.subplot(G[2, 1]).plot(H_train_acc,'-', label="H train",c='pink')
    plt.subplot(G[2, 1]).plot(H_test_acc, '--',label="H test", c='pink')
    plt.subplot(G[2, 1]).plot(I_train_acc,'-', label="I train",c='gold')
    plt.subplot(G[2, 1]).plot(I_test_acc, '--',label="I test", c='gold')
    plt.subplot(G[2, 1]).plot(J_train_acc,'-', label="J train",c='silver')
    plt.subplot(G[2, 1]).plot(H_test_acc, '--',label="J test", c='silver')
    # plt.legend()

    plt.tight_layout()
    plt.show()

# %%
# plot gradient p
plot_everything(Z_gradp,
                    A_gradp,
                    B_gradp,
                    C_gradp,
                    D_gradp,
                    E_gradp,
                    F_gradp,
                    G_gradp,                    
                    H_gradp,
                    I_gradp,
                    J_gradp,'gradientp')

# %%
# plot gradient w
plot_everything(Z_gradw,
                    A_gradw,
                    B_gradw,
                    C_gradw,
                    D_gradw,
                    E_gradw,
                    F_gradw,
                    G_gradw,                    
                    H_gradw,
                    I_gradw,
                    J_gradw,'gradientw')

# %%
# plot layer
plot_everything(Z_layer,
                    A_layer,
                    B_layer,
                    C_layer,
                    D_layer,
                    E_layer,
                    F_layer,
                    G_layer,                    
                    H_layer,
                    I_layer,
                    J_layer,'layer')

# %%
# plot layer a
plot_everything(Z_layera,
                    A_layera,
                    B_layera,
                    C_layera,
                    D_layera,
                    E_layera,
                    F_layera,
                    G_layera,                    
                    H_layera,
                    I_layera,
                    J_layera,'layera')

# %%
# plot weights
plot_everything(Z_weight,
                    A_weight,
                    B_weight,
                    C_weight,
                    D_weight,
                    E_weight,
                    F_weight,
                    G_weight,                    
                    H_weight,
                    I_weight,
                    J_weight,'weight',special=True)

# %%
! start .
