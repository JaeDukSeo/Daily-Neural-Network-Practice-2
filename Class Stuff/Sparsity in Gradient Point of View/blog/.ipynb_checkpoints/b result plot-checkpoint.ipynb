# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
# read Z results 
Z_gradp1 = np.asarray(np.load('Z/gradp1.npy')); Z_gradp2 = np.asarray(np.load('Z/gradp2.npy')); Z_gradp3 = np.asarray(np.load('Z/gradp3.npy'))
Z_gradp4 = np.asarray(np.load('Z/gradp4.npy')); Z_gradp5 = np.asarray(np.load('Z/gradp5.npy')); Z_gradp6 = np.asarray(np.load('Z/gradp6.npy'))

Z_gradw1 = np.asarray(np.load('Z/gradw1.npy')); Z_gradw2 = np.asarray(np.load('Z/gradw2.npy')); Z_gradw3 = np.asarray(np.load('Z/gradw3.npy')); 
Z_gradw4 = np.asarray(np.load('Z/gradw4.npy')); Z_gradw5 = np.asarray(np.load('Z/gradw5.npy')); Z_gradw6 = np.asarray(np.load('Z/gradw6.npy')); 

Z_layer1 = np.asarray(np.load('Z/llayer1.npy')); Z_layer2 = np.asarray(np.load('Z/llayer2.npy'));  Z_layer3 = np.asarray(np.load('Z/llayer3.npy')); 
Z_layer4 = np.asarray(np.load('Z/llayer4.npy')); Z_layer5 = np.asarray(np.load('Z/llayer5.npy'));  Z_layer6 = np.asarray(np.load('Z/llayer6.npy')); 


Z_layera1 = np.asarray(np.load('Z/llayer1a.npy')); 
Z_layera1 = np.asarray(np.load('Z/llayer1a.npy')); 
Z_layera1 = np.asarray(np.load('Z/llayer1a.npy')); 
Z_layera1 = np.asarray(np.load('Z/llayer1a.npy')); 
Z_layera1 = np.asarray(np.load('Z/llayer1a.npy')); 


Z_moment1   = np.asarray(np.load('Z/gradup1.npy')); 

Z_weights1  = np.asarray(np.load('Z/weight1.npy')); 




plt.plot(Z_gradp1[0,:])
plt.plot(Z_gradp2[0,:])
plt.plot(Z_gradp3[0,:])
plt.plot(Z_gradp4[0,:])
plt.plot(Z_gradp5[0,:])
plt.plot(Z_gradp6[0,:])
plt.show()

plt.plot(Z_gradw1[0,:])
plt.plot(Z_gradw2[0,:])
plt.plot(Z_gradw3[0,:])
plt.plot(Z_gradw4[0,:])
plt.plot(Z_gradw5[0,:])
plt.plot(Z_gradw6[0,:])
plt.show()

# %%
! start .
