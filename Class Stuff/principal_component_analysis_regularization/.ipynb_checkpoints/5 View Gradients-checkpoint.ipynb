# %%
# import lib
import tensorflow as tf
import numpy as np
import sys, os,cv2
from sklearn.utils import shuffle
from scipy.misc import imread,imresize
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from skimage.transform import resize
from imgaug import augmenters as iaa
import imgaug as ia
from scipy.ndimage import zoom
from sklearn.utils import shuffle

# %%
# create data
n_examples, hidden_layer_dim = 100, 100
input_dim = 1000
X         = np.random.randn(n_examples, input_dim) # 100 examples of 1000 points
n_layers  = 20
layer_dim = [hidden_layer_dim] * n_layers # each one has 100 neurons

hs = [X]
zs = [X]
ws = []

# %%
# feed forward process 
for i in np.arange(n_layers):
    h = hs[-1] # get the input into this hidden layer
    W = np.random.normal(size = (layer_dim[i], h.shape[0])) * 0.01 # weight init: gaussian around 0
    z = np.dot(W, h)
    h_out = z * (z > 0)
    ws.append(W)
    zs.append(z)
    hs.append(h_out)

# %%
dLdh    = 100 * np.random.randn(hidden_layer_dim, input_dim) # random incoming grad into our last layer
h_grads = [dLdh] # store the incoming grads into each layer
w_grads = [] # store dL/dw for each layer

# %%
# the backwards pass
for i in np.flip(np.arange(1, n_layers), axis = 0):
	# get the incoming gradient
	incoming_loss_grad = h_grads[-1]
	# backprop through the relu
	print(incoming_loss_grad.shape)
	dLdz = incoming_loss_grad * (zs[i] > 0)
	# get the gradient dL/dh_{i-1}, this will be the incoming grad into the next layer
	h_grad = ws[i-1].T.dot(dLdz)
	# get the gradient of the weights of this layer (dL/dw)
	weight_grad = dLdz.dot(hs[i-1].T)
	h_grads.append(h_grad)
	w_grads.append(weight_grad)
# Out:
# (100, 1000)
# (100, 1000)
# (100, 1000)
# (100, 1000)
# (100, 1000)
# (100, 1000)
# (100, 1000)
# (100, 1000)
# (100, 1000)
# (100, 1000)
# (100, 1000)
# (100, 1000)
# (100, 1000)
# (100, 1000)
# (100, 1000)
# (100, 1000)
# (100, 1000)
# (100, 1000)
# (100, 1000)

# %%
# plot the resulting activatiosn
for i, activation in enumerate(hs):
	fig = plt.figure()
	num_bins = 50
	print('variance of linear units before relu is {}'.format(np.var(zs[i].ravel())))
	print('variance of activations is {}'.format(np.var(activation.ravel())))
	ratio = np.var(zs[i].ravel()) / np.var(activation.ravel())
	print('ratio is {}'.format(ratio))
	n, bins, patches = plt.hist(activation.ravel(), num_bins, normed=1, facecolor='green', alpha=0.5)
	plt.title('Activation {}, var: {}'.format(i, np.var(activation.ravel())))
	plt.xlabel('Activation Value')
	plt.ylabel('Number of Activations')
	# Tweak spacing to prevent clipping of ylabel
	plt.subplots_adjust(left=0.15)
	plt.savefig('activation-plots/act-{}.png'.format(i))	
	plt.ticklabel_format(axis='x',style='sci',scilimits=(1,4))
# Out:
# variance of linear units before relu is 0.9944245247673164
# variance of activations is 0.9944245247673164
# ratio is 1.0
# variance of linear units before relu is 0.010057925144155239
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# variance of activations is 0.00342197256186582
# ratio is 2.939218524496639
# variance of linear units before relu is 5.560938430343135e-05
# variance of activations is 1.8031240077189225e-05
# ratio is 3.0840576724271505
# variance of linear units before relu is 2.530121100673569e-07
# variance of activations is 8.839570536593905e-08
# ratio is 2.8622669961164022
# variance of linear units before relu is 1.3265240028188184e-09
# variance of activations is 4.5808185585269497e-10
# ratio is 2.895823062778954
# variance of linear units before relu is 5.526433514470591e-12
# variance of activations is 1.8296709879931636e-12
# ratio is 3.0204520652820452
# variance of linear units before relu is 2.7931590335096284e-14
# variance of activations is 8.650634023584675e-15
# ratio is 3.2288489212403313
# variance of linear units before relu is 1.2485126232469915e-16
# variance of activations is 3.781049731339013e-17
# ratio is 3.302026452862459
# variance of linear units before relu is 5.473749976567632e-19
# variance of activations is 2.1760633570382454e-19
# ratio is 2.515436859346659
# variance of linear units before relu is 3.399705613543275e-21
# variance of activations is 1.1522665347555272e-21
# ratio is 2.95045070823356
# variance of linear units before relu is 1.503550514770114e-23
# variance of activations is 5.033735709742537e-24
# ratio is 2.986947669620535
# variance of linear units before relu is 8.157590443943804e-26
# variance of activations is 3.051275987417677e-26
# ratio is 2.673501340941515
# variance of linear units before relu is 4.413392349420219e-28
# variance of activations is 1.9024607391439171e-28
# ratio is 2.3198336021410824
# variance of linear units before relu is 2.519437220461181e-30
# variance of activations is 7.2437389574477595e-31
# ratio is 3.478089471833857
# variance of linear units before relu is 1.0261243050935243e-32
# variance of activations is 3.423006253053467e-33
# ratio is 2.9977283978905325
# variance of linear units before relu is 5.004180493810959e-35
# variance of activations is 1.843915693707332e-35
# ratio is 2.7138879021901894
# variance of linear units before relu is 2.1690975111786303e-37
# variance of activations is 6.92484745108672e-38
# ratio is 3.1323397757133735
# variance of linear units before relu is 1.0427733523181801e-39
# variance of activations is 3.821046466329624e-40
# ratio is 2.729025573247831
# variance of linear units before relu is 6.023846234859273e-42
# variance of activations is 2.5116007467741152e-42
# ratio is 2.398409159017915
# variance of linear units before relu is 3.755410603641832e-44
# variance of activations is 1.2143158671187607e-44
# ratio is 3.0926142903430835
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# variance of linear units before relu is 1.5761953814744353e-46
# variance of activations is 5.887385003265605e-47
# ratio is 2.677241900436533

# %%
! git add .
! git commit -m "from mac"
! git push
# Out:
# [master 1db22866] from mac
#  24 files changed, 254 insertions(+), 26 deletions(-)
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/.DS_Store
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-0.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-1.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-10.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-11.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-12.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-13.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-14.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-15.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-16.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-17.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-18.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-19.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-2.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-20.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-3.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-4.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-5.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-6.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-7.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-8.png
#  create mode 100644 Class Stuff/principal_component_analysis_regularization/activation-plots/act-9.png
# Counting objects: 29, done.
# Delta compression using up to 4 threads.
# Compressing objects: 100% (29/29), done.
# Writing objects: 100% (29/29), 254.75 KiB | 18.20 MiB/s, done.
# Total 29 (delta 5), reused 0 (delta 0)
# remote: Resolving deltas: 100% (5/5), completed with 5 local objects.
# To https://github.com/JaeDukSeo/Daily-Neural-Network-Practice-2
#    6138618d..1db22866  master -> master
