# %%
# import lib
import numpy as np
import matplotlib.pyplot as plt
import pylab as plot
import matplotlib
plt.style.use('seaborn')

# %%
# read results 1 
caseA_train = np.load('no_batch/A/train.npy'); caseA_test  = np.load('no_batch/A/test.npy')
caseB_train = np.load('no_batch/B/train.npy'); caseB_test  = np.load('no_batch/B/test.npy')
caseC_train = np.load('no_batch/C/train.npy'); caseC_test  = np.load('no_batch/C/test.npy')
caseD_train = np.load('no_batch/D/train.npy'); caseD_test  = np.load('no_batch/D/test.npy')
caseE_train = np.load('no_batch/E/train.npy'); caseE_test  = np.load('no_batch/E/test.npy')

print(caseA_train.shape,caseA_test.shape)
print(caseB_train.shape,caseB_test.shape)
print(caseC_train.shape,caseC_test.shape)
print(caseD_train.shape,caseD_test.shape)
print(caseE_train.shape,caseE_test.shape)
# Out:
# (10, 200) (10, 200)
# (10, 200) (10, 200)
# (10, 200) (10, 200)
# (10, 200) (10, 200)
# (10, 200) (10, 200)

# %%
# plot the training
matplotlib.rcParams.update({'font.size': 100})
params = {'legend.fontsize': 15,'legend.handlelength': 2,'font.size': 100}
plot.rcParams.update(params)
plt.figure(figsize=(10,10))

current_case = caseA_train
plt.plot(current_case.max(0),  ' ' ,color='red')
plt.plot(current_case.mean(0), '-' ,color='red',label='Case A Train')
plt.plot(current_case.min(0) , ' ' ,color='red')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='red', alpha=0.2)

current_case = caseB_train
plt.plot(current_case.max(0),  ' ' ,color='blue')
plt.plot(current_case.mean(0), '-' ,color='blue',label='Case B Train')
plt.plot(current_case.min(0) , ' ' ,color='blue')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='blue', alpha=0.2)

current_case = caseC_train
plt.plot(current_case.max(0),  ' ' ,color='green')
plt.plot(current_case.mean(0), '-' ,color='green',label='Case C Train')
plt.plot(current_case.min(0) , ' ' ,color='green')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='green', alpha=0.2)

current_case = caseD_train
plt.plot(current_case.max(0),  ' ' ,color='black')
plt.plot(current_case.mean(0), '-' ,color='black',label='Case D Train')
plt.plot(current_case.min(0) , ' ' ,color='black')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='black', alpha=0.2)

current_case = caseE_train
plt.plot(current_case.max(0),  ' ' ,color='magenta')
plt.plot(current_case.mean(0), '-' ,color='magenta',label='Case E Train')
plt.plot(current_case.min(0) , ' ' ,color='magenta')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='magenta', alpha=0.2)

plt.legend()
plt.show()

# %%
# plot the std
matplotlib.rcParams.update({'font.size': 100})
params = {'legend.fontsize': 15,'legend.handlelength': 2,'font.size': 100}
plot.rcParams.update(params)
plt.figure(figsize=(10,10))

current_case = caseA_train
plt.plot(current_case.std(0), '-' ,color='red',label='Case A Train')

current_case = caseB_train
plt.plot(current_case.std(0), '-' ,color='blue',label='Case B Train')

current_case = caseC_train
plt.plot(current_case.std(0), '-' ,color='green',label='Case C Train')

current_case = caseD_train
plt.plot(current_case.std(0), '-' ,color='black',label='Case D Train')

current_case = caseE_train
plt.plot(current_case.std(0), '-' ,color='magenta',label='Case E Train')

plt.legend()
plt.show()

# %%
# plot the training
matplotlib.rcParams.update({'font.size': 100})
params = {'legend.fontsize': 15,'legend.handlelength': 2,'font.size': 100}
plot.rcParams.update(params)
plt.figure(figsize=(10,10))

current_case = caseA_test
plt.plot(current_case.max(0),  ' ' ,color='red')
plt.plot(current_case.mean(0), '-' ,color='red',label='Case A Test')
plt.plot(current_case.min(0) , ' ' ,color='red')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='red', alpha=0.2)

current_case = caseB_test
plt.plot(current_case.max(0),  ' ' ,color='blue')
plt.plot(current_case.mean(0), '-' ,color='blue',label='Case B Test')
plt.plot(current_case.min(0) , ' ' ,color='blue')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='blue', alpha=0.2)

current_case = caseC_test
plt.plot(current_case.max(0),  ' ' ,color='green')
plt.plot(current_case.mean(0), '-' ,color='green',label='Case C Test')
plt.plot(current_case.min(0) , ' ' ,color='green')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='green', alpha=0.2)

current_case = caseD_test
plt.plot(current_case.max(0),  ' ' ,color='black')
plt.plot(current_case.mean(0), '-' ,color='black',label='Case D Test')
plt.plot(current_case.min(0) , ' ' ,color='black')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='black', alpha=0.2)

current_case = caseE_test
plt.plot(current_case.max(0),  ' ' ,color='magenta')
plt.plot(current_case.mean(0), '-' ,color='magenta',label='Case E Test')
plt.plot(current_case.min(0) , ' ' ,color='magenta')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='magenta', alpha=0.2)

plt.legend()
plt.show()

# %%
# plot the std
matplotlib.rcParams.update({'font.size': 100})
params = {'legend.fontsize': 15,'legend.handlelength': 2,'font.size': 100}
plot.rcParams.update(params)
plt.figure(figsize=(10,10))

current_case = caseA_test
plt.plot(current_case.std(0), '-' ,color='red',label='Case A Test')

current_case = caseB_test
plt.plot(current_case.std(0), '-' ,color='blue',label='Case B Test')

current_case = caseC_test
plt.plot(current_case.std(0), '-' ,color='green',label='Case C Test')

current_case = caseD_test
plt.plot(current_case.std(0), '-' ,color='black',label='Case D Test')

current_case = caseE_test
plt.plot(current_case.std(0), '-' ,color='magenta',label='Case E Test')

plt.legend()
plt.show()

# %%
# plot the result 2
result2_caseA_train = np.load('act_as_reg/A/train.npy'); result2_caseA_test = np.load('act_as_reg/A/test.npy')
result2_caseB_train = np.load('act_as_reg/B/train.npy'); result2_caseB_test = np.load('act_as_reg/B/test.npy')
result2_caseC_train = np.load('act_as_reg/C/train.npy'); result2_caseC_test = np.load('act_as_reg/C/test.npy')
result2_caseD_train = np.load('act_as_reg/D/train.npy'); result2_caseD_test = np.load('act_as_reg/D/test.npy')
result2_caseE_train = np.load('act_as_reg/E/train.npy'); result2_caseE_test = np.load('act_as_reg/E/test.npy')
result2_caseF_train = np.load('act_as_reg/F/train.npy'); result2_caseF_test = np.load('act_as_reg/F/test.npy')
result2_caseG_train = np.load('act_as_reg/G/train.npy'); result2_caseG_test = np.load('act_as_reg/G/test.npy')
result2_caseH_train = np.load('act_as_reg/H/train.npy'); result2_caseH_test = np.load('act_as_reg/H/test.npy')
result2_caseI_train = np.load('act_as_reg/I/train.npy'); result2_caseI_test = np.load('act_as_reg/I/test.npy')
result2_caseJ_train = np.load('act_as_reg/J/train.npy'); result2_caseJ_test = np.load('act_as_reg/J/test.npy')
result2_caseK_train = np.load('act_as_reg/K/train.npy'); result2_caseK_test = np.load('act_as_reg/K/test.npy')

# %%
# plot the training
matplotlib.rcParams.update({'font.size': 100})
params = {'legend.fontsize': 15,'legend.handlelength': 2,'font.size': 100}
plot.rcParams.update(params)
plt.figure(figsize=(10,10))

current_case = result2_caseA_train
plt.plot(current_case.max(0),  ' ' ,color='red')
plt.plot(current_case.mean(0), '-' ,color='red',label='Case A Train')
plt.plot(current_case.min(0) , ' ' ,color='red')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='red', alpha=0.1)

current_case = result2_caseB_train
plt.plot(current_case.max(0),  ' ' ,color='blue')
plt.plot(current_case.mean(0), '-' ,color='blue',label='Case B Train')
plt.plot(current_case.min(0) , ' ' ,color='blue')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='blue', alpha=0.1)

current_case = result2_caseC_train
plt.plot(current_case.max(0),  ' ' ,color='green')
plt.plot(current_case.mean(0), '-' ,color='green',label='Case C Train')
plt.plot(current_case.min(0) , ' ' ,color='green')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='green', alpha=0.1)

current_case = result2_caseD_train
plt.plot(current_case.max(0),  ' ' ,color='black')
plt.plot(current_case.mean(0), '-' ,color='black',label='Case D Train')
plt.plot(current_case.min(0) , ' ' ,color='black')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='black', alpha=0.1)

current_case = result2_caseE_train
plt.plot(current_case.max(0),  ' ' ,color='magenta')
plt.plot(current_case.mean(0), '-' ,color='magenta',label='Case E Train')
plt.plot(current_case.min(0) , ' ' ,color='magenta')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='magenta', alpha=0.1)

current_case = result2_caseF_train
plt.plot(current_case.max(0),  ' ' ,color='cyan')
plt.plot(current_case.mean(0), '-' ,color='cyan',label='Case F Train')
plt.plot(current_case.min(0) , ' ' ,color='cyan')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='cyan', alpha=0.1)

current_case = result2_caseG_train
plt.plot(current_case.max(0),  ' ' ,color='lightgreen')
plt.plot(current_case.mean(0), '-' ,color='lightgreen',label='Case G Train')
plt.plot(current_case.min(0) , ' ' ,color='lightgreen')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='lightgreen', alpha=0.1)

current_case = result2_caseH_train
plt.plot(current_case.max(0),  ' ' ,color='skyblue')
plt.plot(current_case.mean(0), '-' ,color='skyblue',label='Case H Train')
plt.plot(current_case.min(0) , ' ' ,color='skyblue')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='skyblue', alpha=0.1)

current_case = result2_caseI_train
plt.plot(current_case.max(0),  ' ' ,color='gold')
plt.plot(current_case.mean(0), '-' ,color='gold',label='Case I Train')
plt.plot(current_case.min(0) , ' ' ,color='gold')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='gold', alpha=0.1)

current_case = result2_caseJ_train
plt.plot(current_case.max(0),  ' ' ,color='white')
plt.plot(current_case.mean(0), '-' ,color='white',label='Case J Train')
plt.plot(current_case.min(0) , ' ' ,color='white')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='white', alpha=0.1)

current_case = result2_caseK_train
plt.plot(current_case.max(0),  ' ' ,color='pink')
plt.plot(current_case.mean(0), '-' ,color='pink',label='Case K Train')
plt.plot(current_case.min(0) , ' ' ,color='pink')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='pink', alpha=0.1)

plt.legend()
plt.show()

# %%
# plot the training
matplotlib.rcParams.update({'font.size': 100})
params = {'legend.fontsize': 15,'legend.handlelength': 2,'font.size': 100}
plot.rcParams.update(params)
plt.figure(figsize=(10,10))

current_case = result2_caseA_train
plt.plot(current_case.std(0), '-' ,color='red',label='Case A Train',alpha=0.3)

current_case = result2_caseB_train
plt.plot(current_case.std(0), '-' ,color='blue',label='Case B Train',alpha=0.3)

current_case = result2_caseC_train
plt.plot(current_case.std(0), '-' ,color='green',label='Case C Train',alpha=0.3)

current_case = result2_caseD_train
plt.plot(current_case.std(0), '-' ,color='black',label='Case D Train',alpha=0.3)

current_case = result2_caseE_train
plt.plot(current_case.std(0), '-' ,color='magenta',label='Case E Train',alpha=0.3)

current_case = result2_caseF_train
plt.plot(current_case.std(0), '-' ,color='cyan',label='Case F Train',alpha=0.3)

current_case = result2_caseG_train
plt.plot(current_case.std(0), '-' ,color='lightgreen',label='Case G Train',alpha=0.3)

current_case = result2_caseH_train
plt.plot(current_case.std(0), '-' ,color='skyblue',label='Case H Train',alpha=0.3)

current_case = result2_caseI_train
plt.plot(current_case.std(0), '-' ,color='gold',label='Case I Train',alpha=0.3)

current_case = result2_caseJ_train
plt.plot(current_case.std(0), '-' ,color='white',label='Case J Train',alpha=1.0)

current_case = result2_caseK_train
plt.plot(current_case.std(0), '-' ,color='pink',label='Case K Train',alpha=0.3)

plt.legend()
plt.show()

# %%
# plot the training
matplotlib.rcParams.update({'font.size': 100})
params = {'legend.fontsize': 15,'legend.handlelength': 2,'font.size': 100}
plot.rcParams.update(params)
plt.figure(figsize=(10,10))

current_case = result2_caseA_test
plt.plot(current_case.max(0),  ' ' ,color='red')
plt.plot(current_case.mean(0), '-' ,color='red',label='Case A Train')
plt.plot(current_case.min(0) , ' ' ,color='red')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='red', alpha=0.1)

current_case = result2_caseB_test
plt.plot(current_case.max(0),  ' ' ,color='blue')
plt.plot(current_case.mean(0), '-' ,color='blue',label='Case B Train')
plt.plot(current_case.min(0) , ' ' ,color='blue')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='blue', alpha=0.1)

current_case = result2_caseC_test
plt.plot(current_case.max(0),  ' ' ,color='green')
plt.plot(current_case.mean(0), '-' ,color='green',label='Case C Train')
plt.plot(current_case.min(0) , ' ' ,color='green')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='green', alpha=0.1)

current_case = result2_caseD_test
plt.plot(current_case.max(0),  ' ' ,color='black')
plt.plot(current_case.mean(0), '-' ,color='black',label='Case D Train')
plt.plot(current_case.min(0) , ' ' ,color='black')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='black', alpha=0.1)

current_case = result2_caseE_test
plt.plot(current_case.max(0),  ' ' ,color='magenta')
plt.plot(current_case.mean(0), '-' ,color='magenta',label='Case E Train')
plt.plot(current_case.min(0) , ' ' ,color='magenta')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='magenta', alpha=0.1)

current_case = result2_caseF_test
plt.plot(current_case.max(0),  ' ' ,color='cyan')
plt.plot(current_case.mean(0), '-' ,color='cyan',label='Case F Train')
plt.plot(current_case.min(0) , ' ' ,color='cyan')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='cyan', alpha=0.1)

current_case = result2_caseG_test
plt.plot(current_case.max(0),  ' ' ,color='lightgreen')
plt.plot(current_case.mean(0), '-' ,color='lightgreen',label='Case G Train')
plt.plot(current_case.min(0) , ' ' ,color='lightgreen')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='lightgreen', alpha=0.1)

current_case = result2_caseH_test
plt.plot(current_case.max(0),  ' ' ,color='skyblue')
plt.plot(current_case.mean(0), '-' ,color='skyblue',label='Case H Train')
plt.plot(current_case.min(0) , ' ' ,color='skyblue')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='skyblue', alpha=0.1)

current_case = result2_caseI_test
plt.plot(current_case.max(0),  ' ' ,color='gold')
plt.plot(current_case.mean(0), '-' ,color='gold',label='Case I Train')
plt.plot(current_case.min(0) , ' ' ,color='gold')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='gold', alpha=0.1)

current_case = result2_caseJ_test
plt.plot(current_case.max(0),  ' ' ,color='white')
plt.plot(current_case.mean(0), '-' ,color='white',label='Case J Train')
plt.plot(current_case.min(0) , ' ' ,color='white')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='white', alpha=0.1)

current_case = result2_caseK_test
plt.plot(current_case.max(0),  ' ' ,color='pink')
plt.plot(current_case.mean(0), '-' ,color='pink',label='Case K Train')
plt.plot(current_case.min(0) , ' ' ,color='pink')
plt.fill_between(range(len(current_case[0])),current_case.max(0),current_case.min(0),facecolor='pink', alpha=0.1)

plt.legend()
plt.show()

# %%
# plot the training
matplotlib.rcParams.update({'font.size': 100})
params = {'legend.fontsize': 15,'legend.handlelength': 2,'font.size': 100}
plot.rcParams.update(params)
plt.figure(figsize=(10,10))

current_case = result2_caseA_test
plt.plot(current_case.std(0), '-' ,color='red',label='Case A Train',alpha=0.1)

current_case = result2_caseB_test
plt.plot(current_case.std(0), '-' ,color='blue',label='Case B Train',alpha=0.1)

current_case = result2_caseC_test
plt.plot(current_case.std(0), '-' ,color='green',label='Case C Train',alpha=0.1)

current_case = result2_caseD_test
plt.plot(current_case.std(0), '-' ,color='black',label='Case D Train',alpha=0.1)

current_case = result2_caseE_test
plt.plot(current_case.std(0), '-' ,color='magenta',label='Case E Train',alpha=0.1)

current_case = result2_caseF_test
plt.plot(current_case.std(0), '-' ,color='cyan',label='Case F Train',alpha=0.1)

current_case = result2_caseG_test
plt.plot(current_case.std(0), '-' ,color='lightgreen',label='Case G Train',alpha=0.1)

current_case = result2_caseH_test
plt.plot(current_case.std(0), '-' ,color='skyblue',label='Case H Train',alpha=0.1)

current_case = result2_caseI_test
plt.plot(current_case.std(0), '-' ,color='gold',label='Case I Train',alpha=0.1)

current_case = result2_caseJ_test
plt.plot(current_case.std(0), '-' ,color='white',label='Case J Train',alpha=0.1)

current_case = result2_caseK_test
plt.plot(current_case.std(0), '-' ,color='pink',label='Case K Train',alpha=0.1)

plt.legend()
plt.show()

# %%
# get the best of the best
all_train_data  = np.vstack([
    caseA_train.mean(0),
    caseB_train.mean(0),
    caseC_train.mean(0),
    caseD_train.mean(0),
    caseE_train.mean(0),
    result2_caseA_train.mean(0),
    result2_caseB_train.mean(0),
    result2_caseC_train.mean(0),
    result2_caseD_train.mean(0),
    result2_caseE_train.mean(0),
    result2_caseF_train.mean(0),
    result2_caseG_train.mean(0),
    result2_caseH_train.mean(0),
    result2_caseI_train.mean(0),
    result2_caseJ_train.mean(0),
    result2_caseK_train.mean(0)
]) 

all_test_data = np.vstack([
    caseA_test.mean(0),
    caseB_test.mean(0),
    caseC_test.mean(0),
    caseD_test.mean(0),
    caseE_test.mean(0),
    result2_caseA_test.mean(0),
    result2_caseB_test.mean(0),
    result2_caseC_test.mean(0),
    result2_caseD_test.mean(0),
    result2_caseE_test.mean(0),
    result2_caseF_test.mean(0),
    result2_caseG_test.mean(0),
    result2_caseH_test.mean(0),
    result2_caseI_test.mean(0),
    result2_caseJ_test.mean(0),
    result2_caseK_test.mean(0)
])

best_test_acc = all_test_data.max(1)
where_best_of_best = np.argmax(best_test_acc)
print(best_test_acc)
print('Best Case is : ',where_best_of_best)

best_train_data = all_train_data[where_best_of_best]
best_test_data  = all_test_data [where_best_of_best]

plt.figure(figsize=(10,10))

plt.plot(caseE_train.max(0),  ' ' ,color='red')
plt.plot(caseE_train.mean(0), '-' ,color='red',label='Train Random Sampling Case E')
plt.plot(caseE_train.min(0) , ' ' ,color='red')
plt.fill_between(range(len(caseE_train[0])),caseE_train.max(0),caseE_train.min(0),facecolor='red', alpha=0.2)

plt.plot(caseE_test.max(0),  ' ' ,color='blue')
plt.plot(caseE_test.mean(0), '-' ,color='blue',label='Test Random Sampling Case E')
plt.plot(caseE_test.min(0) , ' ' ,color='blue')
plt.fill_between(range(len(caseE_test[0])),caseE_test.max(0),caseE_test.min(0),facecolor='blue', alpha=0.2)

plt.legend()
plt.show()
# Out:
# [0.4671875 0.470975  0.4747375 0.4897375 0.4927125 0.414325  0.411375
#  0.41455   0.421025  0.419675  0.419525  0.4185    0.419425  0.420375
#  0.420675  0.3578   ]
# Best Case is :  4
